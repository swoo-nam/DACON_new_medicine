# %% [markdown]
# <a href="https://colab.research.google.com/github/swoo-nam/app/blob/master/%EB%82%A8%EC%83%81%EC%9A%B0_BIO_ML_ver5_5(cal)_ensemble2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepchem
# Out:
# Requirement already satisfied: deepchem in c:\python39\lib\site-packages (2.7.1)
# Requirement already satisfied: joblib in c:\python39\lib\site-packages (from deepchem) (1.2.0)
# Requirement already satisfied: numpy>=1.21 in c:\python39\lib\site-packages (from deepchem) (1.24.3)
# Requirement already satisfied: pandas in c:\python39\lib\site-packages (from deepchem) (2.0.1)
# Requirement already satisfied: scikit-learn in c:\python39\lib\site-packages (from deepchem) (1.2.2)
# Requirement already satisfied: scipy<1.9 in c:\python39\lib\site-packages (from deepchem) (1.8.1)
# Requirement already satisfied: rdkit in c:\python39\lib\site-packages (from deepchem) (2023.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python39\lib\site-packages (from pandas->deepchem) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas->deepchem) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python39\lib\site-packages (from pandas->deepchem) (2023.3)
# Requirement already satisfied: Pillow in c:\python39\lib\site-packages (from rdkit->deepchem) (9.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python39\lib\site-packages (from scikit-learn->deepchem) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.16.0)

# %%
# !pip install mordred
# Out:
# Requirement already satisfied: mordred in c:\python39\lib\site-packages (1.2.0)
# Requirement already satisfied: six==1.* in c:\python39\lib\site-packages (from mordred) (1.16.0)
# Requirement already satisfied: numpy==1.* in c:\python39\lib\site-packages (from mordred) (1.24.3)
# Requirement already satisfied: networkx==2.* in c:\python39\lib\site-packages (from mordred) (2.8.8)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\python39\lib\site-packages (1.7.5)
# Requirement already satisfied: numpy in c:\python39\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\python39\lib\site-packages (from xgboost) (1.8.1)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

# DATA_PATH = "/content/drive/MyDrive/project/data/"
DATA_PATH = "C:\python-code\project_bio\data/"

SEED = 42

# %%
train = pd.read_csv(f"{DATA_PATH}train.csv")
test = pd.read_csv(f"{DATA_PATH}test.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
# %config InlineBackend.figure_format = 'retina'
warnings.filterwarnings("ignore")
# %matplotlib inline

from rdkit import Chem, DataStructs
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG=True
from mordred import Calculator, descriptors

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from xgboost import XGBClassifier, XGBRegressor
from sklearn import tree
from flaml import AutoML

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
from sklearn.metrics import mean_squared_error

def rmse(y_valid, pred):
    mse = mean_squared_error(y_valid, pred)
    return np.sqrt(mse)

# %%
from sklearn.metrics import make_scorer

rmse_score = make_scorer(rmse, greater_is_better=False)

# %% [markdown]
# ### -> 이상치 제거 (총 18개)

# %%
# 1. 극단치만 판단해서 18개 제거
outliers = train[(train['MLM'] > 100.0) | (train['HLM'] > 100.0) | (train['AlogP'] < -3) | (train['Molecular_Weight'] > 800)
     | (train['Num_H_Acceptors'] > 14) | (train['Num_H_Donors'] > 9) | (train['Num_RotatableBonds'] > 20)
     | (train['LogD'] < -4) | (train['Molecular_PolarSurfaceArea'] > 250)]

# %%
outliers.index
# Out:
# Index([ 179,  662,  834,  983, 1092, 1172, 1239, 1584, 2159, 2258, 2367, 2410,
#        2586, 2711, 2948, 3157, 3247, 3403],
#       dtype='int64')

# %%
train = train.drop(index=outliers.index, axis=0)

# %%
train.shape # 3498 -> 3480
# Out:
# (3480, 11)

# %%
duplicates = train[train.duplicated(subset=['SMILES'], keep=False)]

duplicates.sort_values(by='SMILES')
# Out:
#               id                                             SMILES     MLM
# 2276  TRAIN_2276                  C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   1.535  \
# 451   TRAIN_0451                  C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.310
# 2891  TRAIN_2891       CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  55.950
# 543   TRAIN_0543       CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  68.485
# 837   TRAIN_0837     CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  63.522
# 366   TRAIN_0366     CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  73.740
# 1085  TRAIN_1085  CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  23.630
# 2848  TRAIN_2848  CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  40.657
# 2096  TRAIN_2096       CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   1.880
# 1666  TRAIN_1666       CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   5.494
# 1285  TRAIN_1285  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  87.987
# 550   TRAIN_0550  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  36.230
# 328   TRAIN_0328  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  86.340
# 2651  TRAIN_2651  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...   0.000
# 859   TRAIN_0859                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.860
# 2362  TRAIN_2362                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   1.819
# 2534  TRAIN_2534  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   5.884
# 565   TRAIN_0565  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   1.000
# 250   TRAIN_0250         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  50.920
# 2245  TRAIN_2245         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  96.170
# 1793  TRAIN_1793  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  82.778
# 1212  TRAIN_1212  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...   0.370
# 1451  TRAIN_1451                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  47.830
# 10    TRAIN_0010                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  56.900
# 1914  TRAIN_1914  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  12.690
# 3035  TRAIN_3035  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...   9.164
# 2756  TRAIN_2756             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  99.000
# 1747  TRAIN_1747             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  65.340
# 2797  TRAIN_2797  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   8.350
# 3161  TRAIN_3161  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   0.000
# 2256  TRAIN_2256        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  55.770
# 2097  TRAIN_2097        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  72.473
# 2805  TRAIN_2805                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   8.144
# 1968  TRAIN_1968                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   0.160
# 2081  TRAIN_2081        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.480
# 450   TRAIN_0450        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.829
# 3445  TRAIN_3445  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  74.080
# 1031  TRAIN_1031  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  99.900
# 106   TRAIN_0106  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   2.904
# 2336  TRAIN_2336  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   0.210
# 2511  TRAIN_2511   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  14.990
# 2780  TRAIN_2780   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N   8.389
# 2672  TRAIN_2672    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  40.150
# 1833  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  16.776
# 1315  TRAIN_1315  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  58.237
# 898   TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  53.850
# 3346  TRAIN_3346  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  80.700
# 2575  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  31.926
# 2850  TRAIN_2850    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  99.900
# 216   TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  40.530
# 3265  TRAIN_3265  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...  10.930
# 2134  TRAIN_2134  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   1.416
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 2276  31.453  3.556           262.309                3             0  \
# 451   24.670  3.556           262.309                3             0
# 2891  69.950  2.172           337.372                4             2
# 543   85.872  2.172           337.372                4             2
# 837   62.488  2.293           367.428                5             2
# 366   66.850  2.293           367.428                5             2
# 1085  71.470  1.684           381.450                7             1
# 2848  99.900  1.684           381.450                7             1
# 2096  61.280  2.843           360.490                3             0
# 1666  25.397  2.843           360.490                3             0
# 1285  85.103  3.750           501.165                5             2
# 550   51.100  3.750           501.165                5             2
# 328   62.260  4.449           381.427                4             1
# 2651   0.000  4.449           381.427                4             1
# 859   35.860  2.484           252.336                4             0
# 2362  37.769  2.484           252.336                4             0
# 2534   1.663  6.727           537.736                3             1
# 565    5.540  6.727           537.736                3             1
# 250    0.929  3.815           402.242                5             0
# 2245   1.340  3.815           402.242                5             0
# 1793  86.729  6.501           496.666                1             1
# 1212   7.540  6.501           496.666                1             1
# 1451  99.000  0.767           294.821                3             1
# 10    40.158  0.767           294.821                3             1
# 1914  12.250  5.374           485.612                7             0
# 3035  17.971  5.374           485.612                7             0
# 2756  91.350 -0.811           336.383                5             0
# 1747  99.900 -0.811           336.383                5             0
# 2797  69.750  4.934           553.444                5             1
# 3161   0.000  4.934           553.444                5             1
# 2256  15.300  2.235           321.333                6             1
# 2097  21.930  2.235           321.333                6             1
# 2805  11.348  2.868           259.324                3             0
# 1968   0.600  2.868           259.324                3             0
# 2081   0.730  2.940           316.348                5             1
# 450    7.530  2.940           316.348                5             1
# 3445  86.260  3.908           408.415                6             1
# 1031  52.633  3.908           408.415                6             1
# 106    4.686  3.219           525.567                6             0
# 2336   0.620  3.219           525.567                6             0
# 2511  18.130  3.322           342.455                4             1
# 2780   4.134  3.322           342.455                4             1
# 2672  32.610  4.609           340.381                4             1
# 1833  15.781  4.609           340.381                4             1
# 1315  60.612  4.282           553.480                5             0
# 898   71.640  4.282           553.480                5             0
# 3346  90.890  4.304           459.520                6             1
# 2575  36.574  4.304           459.520                6             1
# 2850  99.900 -1.133           385.417                7             0
# 216   87.780 -1.133           385.417                7             0
# 3265  20.330  5.630           466.572                4             0
# 2134   1.404  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 2276                   4  3.556                       43.60
# 451                    4  3.556                       43.60
# 2891                   3  2.169                       82.00
# 543                    3  2.169                       82.00
# 837                    3  2.307                      139.85
# 366                    3  2.307                      139.85
# 1085                   4  1.684                      126.52
# 2848                   4  1.684                      126.52
# 2096                   4  2.843                       49.85
# 1666                   4  2.843                       49.85
# 1285                   5  3.750                      106.72
# 550                    5  3.750                      106.72
# 328                    3  4.446                       76.69
# 2651                   3  4.446                       76.69
# 859                    4  2.474                       73.56
# 2362                   4  2.474                       73.56
# 2534                   6  6.727                      120.05
# 565                    6  6.727                      120.05
# 250                    6  3.819                       74.08
# 2245                   6  3.819                       74.08
# 1793                   4  6.501                       68.74
# 1212                   4  6.501                       68.74
# 1451                   3  0.388                       86.03
# 10                     3  0.388                       86.03
# 1914                  13  3.870                       66.46
# 3035                  13  3.870                       66.46
# 2756                   5 -0.811                       68.31
# 1747                   5 -0.811                       68.31
# 2797                   7  4.934                       73.17
# 3161                   7  4.934                       73.17
# 2256                   4  1.806                       85.28
# 2097                   4  1.806                       85.28
# 2805                   3  2.868                       59.06
# 1968                   3  2.868                       59.06
# 2081                   4  2.940                       57.15
# 450                    4  2.940                       57.15
# 3445                   4  3.909                       98.81
# 1031                   4  3.909                       98.81
# 106                    7  3.086                       88.19
# 2336                   7  3.086                       88.19
# 2511                   4  3.322                       95.26
# 2780                   4  3.322                       95.26
# 2672                   2  4.736                       71.75
# 1833                   2  4.736                       71.75
# 1315                   7  4.009                       65.98
# 898                    7  4.009                       65.98
# 3346                   4  4.304                      113.53
# 2575                   4  4.304                      113.53
# 2850                   4 -1.133                      108.65
# 216                    4 -1.133                      108.65
# 3265                   8  5.630                       94.90
# 2134                   8  5.630                       94.90

# %%
processed_duplicate = duplicates.groupby('SMILES')[['MLM', 'HLM']].mean().reset_index()
processed_duplicate
# Out:
#                                                SMILES      MLM      HLM
# 0                   C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.9225  28.0615
# 1        CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  62.2175  77.9110
# 2      CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  68.6310  64.6690
# 3   CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  32.1435  85.6850
# 4        CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   3.6870  43.3385
# 5   CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  62.1085  68.1015
# 6   CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  43.1700  31.1300
# 7                       CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.3395  36.8145
# 8   CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   3.4420   3.6015
# 9          CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  73.5450   1.1345
# 10  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  41.5740  47.1345
# 11                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  52.3650  69.5790
# 12  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  10.9270  15.1105
# 13             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  82.1700  95.6250
# 14  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   4.1750  34.8750
# 15        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  64.1215  18.6150
# 16                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   4.1520   5.9740
# 17        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.6545   4.1300
# 18  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  86.9900  69.4465
# 19  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   1.5570   2.6530
# 20   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  11.6895  11.1320
# 21    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630  24.1955
# 22  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435  66.1260
# 23  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130  63.7320
# 24    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150  93.8400
# 25  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730  10.8670

# %%
tmp = pd.merge(processed_duplicate,duplicates,how='left',on='SMILES')
tmp
# Out:
#                                                SMILES    MLM_x    HLM_x
# 0                   C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.9225  28.0615  \
# 1                   C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.9225  28.0615
# 2        CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  62.2175  77.9110
# 3        CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  62.2175  77.9110
# 4      CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  68.6310  64.6690
# 5      CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  68.6310  64.6690
# 6   CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  32.1435  85.6850
# 7   CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  32.1435  85.6850
# 8        CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   3.6870  43.3385
# 9        CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   3.6870  43.3385
# 10  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  62.1085  68.1015
# 11  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  62.1085  68.1015
# 12  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  43.1700  31.1300
# 13  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  43.1700  31.1300
# 14                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.3395  36.8145
# 15                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.3395  36.8145
# 16  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   3.4420   3.6015
# 17  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   3.4420   3.6015
# 18         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  73.5450   1.1345
# 19         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  73.5450   1.1345
# 20  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  41.5740  47.1345
# 21  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  41.5740  47.1345
# 22                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  52.3650  69.5790
# 23                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  52.3650  69.5790
# 24  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  10.9270  15.1105
# 25  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  10.9270  15.1105
# 26             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  82.1700  95.6250
# 27             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  82.1700  95.6250
# 28  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   4.1750  34.8750
# 29  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   4.1750  34.8750
# 30        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  64.1215  18.6150
# 31        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  64.1215  18.6150
# 32                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   4.1520   5.9740
# 33                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   4.1520   5.9740
# 34        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.6545   4.1300
# 35        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.6545   4.1300
# 36  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  86.9900  69.4465
# 37  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  86.9900  69.4465
# 38  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   1.5570   2.6530
# 39  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   1.5570   2.6530
# 40   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  11.6895  11.1320
# 41   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  11.6895  11.1320
# 42    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630  24.1955
# 43    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630  24.1955
# 44  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435  66.1260
# 45  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435  66.1260
# 46  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130  63.7320
# 47  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130  63.7320
# 48    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150  93.8400
# 49    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150  93.8400
# 50  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730  10.8670
# 51  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730  10.8670
#
#             id   MLM_y   HLM_y  AlogP  Molecular_Weight  Num_H_Acceptors
# 0   TRAIN_0451   0.310  24.670  3.556           262.309                3  \
# 1   TRAIN_2276   1.535  31.453  3.556           262.309                3
# 2   TRAIN_0543  68.485  85.872  2.172           337.372                4
# 3   TRAIN_2891  55.950  69.950  2.172           337.372                4
# 4   TRAIN_0366  73.740  66.850  2.293           367.428                5
# 5   TRAIN_0837  63.522  62.488  2.293           367.428                5
# 6   TRAIN_1085  23.630  71.470  1.684           381.450                7
# 7   TRAIN_2848  40.657  99.900  1.684           381.450                7
# 8   TRAIN_1666   5.494  25.397  2.843           360.490                3
# 9   TRAIN_2096   1.880  61.280  2.843           360.490                3
# 10  TRAIN_0550  36.230  51.100  3.750           501.165                5
# 11  TRAIN_1285  87.987  85.103  3.750           501.165                5
# 12  TRAIN_0328  86.340  62.260  4.449           381.427                4
# 13  TRAIN_2651   0.000   0.000  4.449           381.427                4
# 14  TRAIN_0859   2.860  35.860  2.484           252.336                4
# 15  TRAIN_2362   1.819  37.769  2.484           252.336                4
# 16  TRAIN_0565   1.000   5.540  6.727           537.736                3
# 17  TRAIN_2534   5.884   1.663  6.727           537.736                3
# 18  TRAIN_0250  50.920   0.929  3.815           402.242                5
# 19  TRAIN_2245  96.170   1.340  3.815           402.242                5
# 20  TRAIN_1212   0.370   7.540  6.501           496.666                1
# 21  TRAIN_1793  82.778  86.729  6.501           496.666                1
# 22  TRAIN_0010  56.900  40.158  0.767           294.821                3
# 23  TRAIN_1451  47.830  99.000  0.767           294.821                3
# 24  TRAIN_1914  12.690  12.250  5.374           485.612                7
# 25  TRAIN_3035   9.164  17.971  5.374           485.612                7
# 26  TRAIN_1747  65.340  99.900 -0.811           336.383                5
# 27  TRAIN_2756  99.000  91.350 -0.811           336.383                5
# 28  TRAIN_2797   8.350  69.750  4.934           553.444                5
# 29  TRAIN_3161   0.000   0.000  4.934           553.444                5
# 30  TRAIN_2097  72.473  21.930  2.235           321.333                6
# 31  TRAIN_2256  55.770  15.300  2.235           321.333                6
# 32  TRAIN_1968   0.160   0.600  2.868           259.324                3
# 33  TRAIN_2805   8.144  11.348  2.868           259.324                3
# 34  TRAIN_0450   0.829   7.530  2.940           316.348                5
# 35  TRAIN_2081   0.480   0.730  2.940           316.348                5
# 36  TRAIN_1031  99.900  52.633  3.908           408.415                6
# 37  TRAIN_3445  74.080  86.260  3.908           408.415                6
# 38  TRAIN_0106   2.904   4.686  3.219           525.567                6
# 39  TRAIN_2336   0.210   0.620  3.219           525.567                6
# 40  TRAIN_2511  14.990  18.130  3.322           342.455                4
# 41  TRAIN_2780   8.389   4.134  3.322           342.455                4
# 42  TRAIN_1833  16.776  15.781  4.609           340.381                4
# 43  TRAIN_2672  40.150  32.610  4.609           340.381                4
# 44  TRAIN_0898  53.850  71.640  4.282           553.480                5
# 45  TRAIN_1315  58.237  60.612  4.282           553.480                5
# 46  TRAIN_2575  31.926  36.574  4.304           459.520                6
# 47  TRAIN_3346  80.700  90.890  4.304           459.520                6
# 48  TRAIN_0216  40.530  87.780 -1.133           385.417                7
# 49  TRAIN_2850  99.900  99.900 -1.133           385.417                7
# 50  TRAIN_2134   1.416   1.404  5.630           466.572                4
# 51  TRAIN_3265  10.930  20.330  5.630           466.572                4
#
#     Num_H_Donors  Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 0              0                   4  3.556                       43.60
# 1              0                   4  3.556                       43.60
# 2              2                   3  2.169                       82.00
# 3              2                   3  2.169                       82.00
# 4              2                   3  2.307                      139.85
# 5              2                   3  2.307                      139.85
# 6              1                   4  1.684                      126.52
# 7              1                   4  1.684                      126.52
# 8              0                   4  2.843                       49.85
# 9              0                   4  2.843                       49.85
# 10             2                   5  3.750                      106.72
# 11             2                   5  3.750                      106.72
# 12             1                   3  4.446                       76.69
# 13             1                   3  4.446                       76.69
# 14             0                   4  2.474                       73.56
# 15             0                   4  2.474                       73.56
# 16             1                   6  6.727                      120.05
# 17             1                   6  6.727                      120.05
# 18             0                   6  3.819                       74.08
# 19             0                   6  3.819                       74.08
# 20             1                   4  6.501                       68.74
# 21             1                   4  6.501                       68.74
# 22             1                   3  0.388                       86.03
# 23             1                   3  0.388                       86.03
# 24             0                  13  3.870                       66.46
# 25             0                  13  3.870                       66.46
# 26             0                   5 -0.811                       68.31
# 27             0                   5 -0.811                       68.31
# 28             1                   7  4.934                       73.17
# 29             1                   7  4.934                       73.17
# 30             1                   4  1.806                       85.28
# 31             1                   4  1.806                       85.28
# 32             0                   3  2.868                       59.06
# 33             0                   3  2.868                       59.06
# 34             1                   4  2.940                       57.15
# 35             1                   4  2.940                       57.15
# 36             1                   4  3.909                       98.81
# 37             1                   4  3.909                       98.81
# 38             0                   7  3.086                       88.19
# 39             0                   7  3.086                       88.19
# 40             1                   4  3.322                       95.26
# 41             1                   4  3.322                       95.26
# 42             1                   2  4.736                       71.75
# 43             1                   2  4.736                       71.75
# 44             0                   7  4.009                       65.98
# 45             0                   7  4.009                       65.98
# 46             1                   4  4.304                      113.53
# 47             1                   4  4.304                      113.53
# 48             0                   4 -1.133                      108.65
# 49             0                   4 -1.133                      108.65
# 50             0                   8  5.630                       94.90
# 51             0                   8  5.630                       94.90

# %% [markdown]
# ### -> 중복치 제거 (총 26개)

# %%
tmp = tmp.iloc[0::2]  # 첫 번째 행부터 시작하여 2씩 증가하여 행 선택
tmp.drop(['MLM_y','HLM_y'],axis =1,inplace=True)

# %%
train = train.drop_duplicates(subset=['SMILES'], keep=False) #기존 train에서 중복치들을 우선 모두 제거
train.shape
# Out:
# (3428, 11)

# %%
train
# Out:
#               id                                             SMILES     MLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
# ...          ...                                                ...     ...
# 3493  TRAIN_3493     Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl   1.556
# 3494  TRAIN_3494  CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...  35.560
# 3495  TRAIN_3495                       CCOC(=O)CCCc1nc2cc(N)ccc2n1C  56.150
# 3496  TRAIN_3496                     Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl   0.030
# 3497  TRAIN_3497                   COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1   0.450
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     50.680  3.259           400.495                5             2  \
# 1     50.590  2.169           301.407                2             1
# 2     80.892  1.593           297.358                5             0
# 3      2.000  4.771           494.652                6             0
# 4     99.990  2.335           268.310                3             0
# ...      ...    ...               ...              ...           ...
# 3493   3.079  3.409           396.195                3             1
# 3494  47.630  1.912           359.381                4             1
# 3495   1.790  1.941           261.320                3             1
# 3496   2.770  0.989           284.696                5             1
# 3497   2.650  4.321           295.399                2             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 0                      8  3.259                      117.37
# 1                      2  2.172                       73.47
# 2                      3  1.585                       62.45
# 3                      5  3.475                       92.60
# 4                      1  2.337                       42.43
# ...                  ...    ...                         ...
# 3493                   5  3.409                       64.74
# 3494                   3  1.844                       77.37
# 3495                   6  2.124                       70.14
# 3496                   5  0.989                       91.51
# 3497                   4  4.321                       50.36
#
# [3428 rows x 11 columns]

# %%
tmp
# Out:
#                                                SMILES    MLM_x    HLM_x
# 0                   C(=C/c1nnn(Cc2ccccc2)n1)\c1ccccc1   0.9225  28.0615  \
# 2        CC(=O)Nc1ccc(N2N=C(c3ccc(O)cc3)C(C)CC2=O)cc1  62.2175  77.9110
# 4      CC(=O)Nc1nc2ccc(-c3nn(C(C)C)c4nc(N)ncc34)cc2s1  68.6310  64.6690
# 6   CC(C)(C)OC(=O)N1CCC(c2n[nH]c3nc(S(C)(=O)=O)ncc...  32.1435  85.6850
# 8        CC(C)COc1cc(=O)n2c(c1C(=O)N1CCC(C)CC1)CCCCC2   3.6870  43.3385
# 10  CC(C)NC(=O)c1c(Cl)nn(C)c1NC(=O)c1cc(Br)nn1-c1n...  62.1085  68.1015
# 12  CC1CC(=O)N(c2ccc(-c3cccc(C#N)c3)cc2)N=C1c1ccc(...  43.1700  31.1300
# 14                      CCCCC/N=c1\n(C)c(=O)nc2sccn12   2.3395  36.8145
# 16  CCOC(=O)CC1(NC(=O)N2Cc3c(sc4c3CCCC4)-n3cccc3C2...   3.4420   3.6015
# 18         CCc1nc2cc(Br)c(C(=O)OC)nc2n1CC(=O)c1ccccc1  73.5450   1.1345
# 20  CN(C)c1ccc(C2c3cccn3-c3sc4c(c3CN2C(=O)NCc2cccc...  41.5740  47.1345
# 22                   CN(C1CCNCC1)S(=O)(=O)c1ccc(Cl)s1  52.3650  69.5790
# 24  COC(=O)C1(CCCN(C)CCc2ccc(OC)c(OC)c2)CCCc2c1ccc...  10.9270  15.1105
# 26             COCCOc1cc(=O)n2c(c1C(=O)N1CCCC1)CCOCC2  82.1700  95.6250
# 28  COc1cc(CN2CCC(NC(=O)c3cc4cc(Br)c5ccccc5c4o3)CC...   4.1750  34.8750
# 30        COc1ccc(C2=NOC(c3ccc(-c4nnn[nH]4)cc3)C2)cc1  64.1215  18.6150
# 32                      COc1ccc(C2=NOC(c3ccsc3)C2)cc1   4.1520   5.9740
# 34        COc1ccc([C@H]2Oc3cc(OC)cc(OC)c3C[C@H]2O)cc1   0.6545   4.1300
# 36  COc1cccc(-c2cc(-c3nc4c5cnn(-c6ccccc6)c5ncn4n3)...  86.9900  69.4465
# 38  CS(=O)(=O)N1CCN(CCOc2ccc3c(c2)C(c2cc(F)cc(F)c2...   1.5570   2.6530
# 40   Cc1cc(=O)[nH]c(SCC(=O)C23CC4CC(CC(C4)C2)C3)c1C#N  11.6895  11.1320
# 42    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630  24.1955
# 44  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435  66.1260
# 46  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130  63.7320
# 48    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150  93.8400
# 50  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730  10.8670
#
#             id  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0   TRAIN_0451  3.556           262.309                3             0  \
# 2   TRAIN_0543  2.172           337.372                4             2
# 4   TRAIN_0366  2.293           367.428                5             2
# 6   TRAIN_1085  1.684           381.450                7             1
# 8   TRAIN_1666  2.843           360.490                3             0
# 10  TRAIN_0550  3.750           501.165                5             2
# 12  TRAIN_0328  4.449           381.427                4             1
# 14  TRAIN_0859  2.484           252.336                4             0
# 16  TRAIN_0565  6.727           537.736                3             1
# 18  TRAIN_0250  3.815           402.242                5             0
# 20  TRAIN_1212  6.501           496.666                1             1
# 22  TRAIN_0010  0.767           294.821                3             1
# 24  TRAIN_1914  5.374           485.612                7             0
# 26  TRAIN_1747 -0.811           336.383                5             0
# 28  TRAIN_2797  4.934           553.444                5             1
# 30  TRAIN_2097  2.235           321.333                6             1
# 32  TRAIN_1968  2.868           259.324                3             0
# 34  TRAIN_0450  2.940           316.348                5             1
# 36  TRAIN_1031  3.908           408.415                6             1
# 38  TRAIN_0106  3.219           525.567                6             0
# 40  TRAIN_2511  3.322           342.455                4             1
# 42  TRAIN_1833  4.609           340.381                4             1
# 44  TRAIN_0898  4.282           553.480                5             0
# 46  TRAIN_2575  4.304           459.520                6             1
# 48  TRAIN_0216 -1.133           385.417                7             0
# 50  TRAIN_2134  5.630           466.572                4             0
#
#     Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 0                    4  3.556                       43.60
# 2                    3  2.169                       82.00
# 4                    3  2.307                      139.85
# 6                    4  1.684                      126.52
# 8                    4  2.843                       49.85
# 10                   5  3.750                      106.72
# 12                   3  4.446                       76.69
# 14                   4  2.474                       73.56
# 16                   6  6.727                      120.05
# 18                   6  3.819                       74.08
# 20                   4  6.501                       68.74
# 22                   3  0.388                       86.03
# 24                  13  3.870                       66.46
# 26                   5 -0.811                       68.31
# 28                   7  4.934                       73.17
# 30                   4  1.806                       85.28
# 32                   3  2.868                       59.06
# 34                   4  2.940                       57.15
# 36                   4  3.909                       98.81
# 38                   7  3.086                       88.19
# 40                   4  3.322                       95.26
# 42                   2  4.736                       71.75
# 44                   7  4.009                       65.98
# 46                   4  4.304                      113.53
# 48                   4 -1.133                      108.65
# 50                   8  5.630                       94.90

# %%
tmp.rename(columns={'HLM_x': 'HLM', 'MLM_x': 'MLM'}, inplace=True)

# %%
train = pd.concat([train, tmp], axis=0, ignore_index=True)
train.shape
# Out:
# (3454, 11)

# %%
train
# Out:
#               id                                             SMILES      MLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.0100  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.2700
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.5860
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.7100
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.2700
# ...          ...                                                ...      ...
# 3449  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630
# 3450  TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435
# 3451  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130
# 3452  TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150
# 3453  TRAIN_2134  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730
#
#           HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     50.6800  3.259           400.495                5             2  \
# 1     50.5900  2.169           301.407                2             1
# 2     80.8920  1.593           297.358                5             0
# 3      2.0000  4.771           494.652                6             0
# 4     99.9900  2.335           268.310                3             0
# ...       ...    ...               ...              ...           ...
# 3449  24.1955  4.609           340.381                4             1
# 3450  66.1260  4.282           553.480                5             0
# 3451  63.7320  4.304           459.520                6             1
# 3452  93.8400 -1.133           385.417                7             0
# 3453  10.8670  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 0                      8  3.259                      117.37
# 1                      2  2.172                       73.47
# 2                      3  1.585                       62.45
# 3                      5  3.475                       92.60
# 4                      1  2.337                       42.43
# ...                  ...    ...                         ...
# 3449                   2  4.736                       71.75
# 3450                   7  4.009                       65.98
# 3451                   4  4.304                      113.53
# 3452                   4 -1.133                      108.65
# 3453                   8  5.630                       94.90
#
# [3454 rows x 11 columns]

# %%
# train.to_csv(f"{DATA_PATH}train_clean.csv", index=False)

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# ## Clean data(예슬)

# %%
train_df = pd.read_csv(f'{DATA_PATH}train_clean.csv')
test_df = pd.read_csv(f'{DATA_PATH}test.csv')
train_df
# Out:
#               id                                             SMILES      MLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.0100  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.2700
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.5860
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.7100
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.2700
# ...          ...                                                ...      ...
# 3449  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630
# 3450  TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435
# 3451  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130
# 3452  TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150
# 3453  TRAIN_2134  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730
#
#           HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     50.6800  3.259           400.495                5             2  \
# 1     50.5900  2.169           301.407                2             1
# 2     80.8920  1.593           297.358                5             0
# 3      2.0000  4.771           494.652                6             0
# 4     99.9900  2.335           268.310                3             0
# ...       ...    ...               ...              ...           ...
# 3449  24.1955  4.609           340.381                4             1
# 3450  66.1260  4.282           553.480                5             0
# 3451  63.7320  4.304           459.520                6             1
# 3452  93.8400 -1.133           385.417                7             0
# 3453  10.8670  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 0                      8  3.259                      117.37
# 1                      2  2.172                       73.47
# 2                      3  1.585                       62.45
# 3                      5  3.475                       92.60
# 4                      1  2.337                       42.43
# ...                  ...    ...                         ...
# 3449                   2  4.736                       71.75
# 3450                   7  4.009                       65.98
# 3451                   4  4.304                      113.53
# 3452                   4 -1.133                      108.65
# 3453                   8  5.630                       94.90
#
# [3454 rows x 11 columns]

# %%
train_df.isnull().sum().sum() , test_df.isnull().sum().sum()
# Out:
# (2, 1)

# %%
sns.set_style('whitegrid')

# %% [markdown]
# # 피쳐 엔지니어링

# %%
calc = Calculator(descriptors, ignore_3D=False)
len(calc.descriptors)
# Out:
# 1826

# %%
x_train = calc.pandas([Chem.MolFromSmiles(x) for x in train_df.SMILES])
x_train
# Out:
#   7%|▋         | 245/3454 [00:23<09:16,  5.76it/s]
# c:\python39\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 3454/3454 [03:58<00:00, 14.47it/s]
#                                                     ABC
# 0     module 'numpy' has no attribute 'float'.\n`np....  \
# 1     module 'numpy' has no attribute 'float'.\n`np....
# 2     module 'numpy' has no attribute 'float'.\n`np....
# 3     module 'numpy' has no attribute 'float'.\n`np....
# 4     module 'numpy' has no attribute 'float'.\n`np....
# ...                                                 ...
# 3449  module 'numpy' has no attribute 'float'.\n`np....
# 3450  module 'numpy' has no attribute 'float'.\n`np....
# 3451  module 'numpy' has no attribute 'float'.\n`np....
# 3452  module 'numpy' has no attribute 'float'.\n`np....
# 3453  module 'numpy' has no attribute 'float'.\n`np....
#
#                                                   ABCGG  nAcid  nBase
# 0     module 'numpy' has no attribute 'float'.\n`np....      0      0  \
# 1     module 'numpy' has no attribute 'float'.\n`np....      0      0
# 2     module 'numpy' has no attribute 'float'.\n`np....      2      1
# 3     module 'numpy' has no attribute 'float'.\n`np....      0      1
# 4     module 'numpy' has no attribute 'float'.\n`np....      0      0
# ...                                                 ...    ...    ...
# 3449  module 'numpy' has no attribute 'float'.\n`np....      0      0
# 3450  module 'numpy' has no attribute 'float'.\n`np....      0      1
# 3451  module 'numpy' has no attribute 'float'.\n`np....      0      0
# 3452  module 'numpy' has no attribute 'float'.\n`np....      0      0
# 3453  module 'numpy' has no attribute 'float'.\n`np....      0      0
#
#         SpAbs_A   SpMax_A  SpDiam_A     SpAD_A   SpMAD_A   LogEE_A  ...
# 0     35.689316  2.421199  4.745523  35.689316  1.274618  4.249154  ...  \
# 1     26.575899  2.426398  4.757199  26.575899  1.265519  3.984419  ...
# 2     29.802128  2.510668  4.982923  29.802128  1.354642  4.049690  ...
# 3     45.884166  2.532483  4.973440  45.884166  1.310976  4.500758  ...
# 4     26.308663  2.452930  4.905860  26.308663  1.315433  3.935574  ...
# ...         ...       ...       ...        ...       ...       ...  ...
# 3449  34.830344  2.505234  4.893210  34.830344  1.339629  4.230453  ...
# 3450  49.727575  2.459083  4.917437  49.727575  1.308620  4.573511  ...
# 3451  42.601740  2.550795  5.037779  42.601740  1.290962  4.451467  ...
# 3452  37.175575  2.442418  4.727992  37.175575  1.327699  4.270653  ...
# 3453  41.469898  2.438686  4.816338  41.469898  1.295934  4.398941  ...
#
#           SRW10     TSRW10          MW       AMW  WPath  WPol  Zagreb1
# 0     10.081676  78.761075  400.156912  7.695325   2380    40    142.0  \
# 1      9.907828  69.149596  301.124883  7.528122    870    35    112.0
# 2     10.144510  70.158066  297.170194  7.248054   1028    36    120.0
# 3     10.613467  86.199585  494.246395  7.162991   4170    61    192.0
# 4      9.978363  53.872357  268.121178  7.447810    762    32    106.0
# ...         ...        ...         ...       ...    ...   ...      ...
# 3449  10.344674  77.430819  340.143645  8.098658   1730    43    148.0
# 3450  10.593756  88.164476  552.169496  8.120140   4874    63    204.0
# 3451  10.677177  84.226168  459.136511  8.502528   2888    61    186.0
# 3452  10.177818  79.094663  385.175004  7.552451   2262    42    148.0
# 3453  10.410937  83.783308  466.102099  8.631520   3644    49    170.0
#
#       Zagreb2   mZagreb1  mZagreb2
# 0       165.0   9.500000  6.361111
# 1       132.0   7.138889  4.527778
# 2       145.0   5.277778  4.888889
# 3       231.0  10.784722  7.500000
# 4       125.0   6.277778  4.361111
# ...       ...        ...       ...
# 3449    180.0   6.611111  5.500000
# 3450    242.0  12.055556  8.222222
# 3451    227.0  10.895833  6.944444
# 3452    175.0   8.000000  6.222222
# 3453    200.0   9.791667  6.916667
#
# [3454 rows x 1826 columns]

# %%
x_test = calc.pandas([Chem.MolFromSmiles(x) for x in test_df.SMILES])
x_test
# Out:
# 100%|██████████| 483/483 [00:32<00:00, 14.91it/s]
#                                                    ABC
# 0    module 'numpy' has no attribute 'float'.\n`np....  \
# 1    module 'numpy' has no attribute 'float'.\n`np....
# 2    module 'numpy' has no attribute 'float'.\n`np....
# 3    module 'numpy' has no attribute 'float'.\n`np....
# 4    module 'numpy' has no attribute 'float'.\n`np....
# ..                                                 ...
# 478  module 'numpy' has no attribute 'float'.\n`np....
# 479  module 'numpy' has no attribute 'float'.\n`np....
# 480  module 'numpy' has no attribute 'float'.\n`np....
# 481  module 'numpy' has no attribute 'float'.\n`np....
# 482  module 'numpy' has no attribute 'float'.\n`np....
#
#                                                  ABCGG  nAcid  nBase
# 0    module 'numpy' has no attribute 'float'.\n`np....      0      1  \
# 1    module 'numpy' has no attribute 'float'.\n`np....      0      0
# 2    module 'numpy' has no attribute 'float'.\n`np....      0      3
# 3    module 'numpy' has no attribute 'float'.\n`np....      0      0
# 4    module 'numpy' has no attribute 'float'.\n`np....      0      1
# ..                                                 ...    ...    ...
# 478  module 'numpy' has no attribute 'float'.\n`np....      0      0
# 479  module 'numpy' has no attribute 'float'.\n`np....      0      1
# 480  module 'numpy' has no attribute 'float'.\n`np....      0      0
# 481  module 'numpy' has no attribute 'float'.\n`np....      0      0
# 482  module 'numpy' has no attribute 'float'.\n`np....      0      2
#
#        SpAbs_A   SpMax_A  SpDiam_A     SpAD_A   SpMAD_A   LogEE_A  ...
# 0    32.037339  2.392367  4.778964  32.037339  1.281494  4.137716  ...  \
# 1    35.824667  2.462328  4.912724  35.824667  1.326840  4.240550  ...
# 2    32.761443  2.378577  4.757154  32.761443  1.260056  4.175318  ...
# 3    35.577061  2.496055  4.855755  35.577061  1.368349  4.227377  ...
# 4    34.235212  2.546495  4.990622  34.235212  1.316739  4.210465  ...
# ..         ...       ...       ...        ...       ...       ...  ...
# 478  28.248662  2.381151  4.715751  28.248662  1.284030  3.995519  ...
# 479  29.983837  2.559820  5.003321  29.983837  1.249327  4.116090  ...
# 480  33.716988  2.612365  5.113784  33.716988  1.296807  4.210713  ...
# 481  24.141151  2.379239  4.758478  24.141151  1.207058  3.909645  ...
# 482  22.745617  2.313193  4.579581  22.745617  1.263645  3.800919  ...
#
#          SRW10     TSRW10          MW        AMW  WPath  WPol  Zagreb1
# 0     9.935713  72.422574  361.193631   6.946031   1607    34    126.0  \
# 1    10.330421  76.111616  370.152872   7.554140   1853    45    146.0
# 2    10.008163  60.614034  347.174610   7.386694   1905    37    132.0
# 3    10.288444  77.464779  345.133808   8.417898   1673    42    146.0
# 4    10.380312  75.874629  353.185175   7.207861   1656    47    144.0
# ..         ...        ...         ...        ...    ...   ...      ...
# 478   9.862509  69.656439  306.230728   5.889052   1138    32    108.0
# 479  10.288852  73.647870  335.184506   6.840500   1280    42    130.0
# 480  10.447235  76.277596  349.142641   7.758725   1469    48    144.0
# 481   9.874728  53.565348  339.985883  11.332863    826    31    102.0
# 482   9.478763  63.502070  250.204513   5.686466    660    22     88.0
#
#      Zagreb2  mZagreb1  mZagreb2
# 0      144.0  7.527778  5.638889
# 1      175.0  7.840278  5.972222
# 2      150.0  8.388889  5.722222
# 3      177.0  6.000000  5.583333
# 4      176.0  8.722222  5.638889
# ..       ...       ...       ...
# 478    125.0  7.756944  5.222222
# 479    157.0  9.201389  5.180556
# 480    177.0  8.722222  5.611111
# 481    118.0  8.388889  4.361111
# 482     99.0  6.055556  4.055556
#
# [483 rows x 1826 columns]

# %%
# 복사
train_x = x_train.copy()
test_x = x_test.copy()

# invalid value encountered in scalar divide 로 채워진 행 삭제
train_x = train_x.drop(1396).reset_index(drop=True)

# obj_cols
obj_cols = train_x.select_dtypes(include=['object']).columns
obj_cols = obj_cols.union(test_x.select_dtypes(include=['object']).columns) # 테스트셋과의 합집합
obj_cols
# Out:
# Index(['AATS6Z', 'AATS6are', 'AATS6d', 'AATS6dv', 'AATS6i', 'AATS6m', 'AATS6p',
#        'AATS6pe', 'AATS6s', 'AATS6se',
#        ...
#        'WNSA1', 'WNSA2', 'WNSA3', 'WNSA4', 'WNSA5', 'WPSA1', 'WPSA2', 'WPSA3',
#        'WPSA4', 'WPSA5'],
#       dtype='object', length=577)

# %%
train_x[obj_cols] = train_x[obj_cols].astype(float)
test_x[obj_cols] = test_x[obj_cols].astype(float)

# train_x = train_x.drop(columns=obj_cols)
# test_x = test_x.drop(columns=obj_cols)

# %%
# # 엑셀로도 저장해서 확인해보기
# with pd.ExcelWriter(f"{DATA_PATH}obj.xlsx", engine='openpyxl') as writer:
#     train_x[obj_cols].to_excel(writer, sheet_name='시트1', index=False)

# %%
# 결측치 채우기
train_x = train_x.fillna(0)
test_x = test_x.fillna(0)

# %%
# 0 으로만 구성된 컬럼은 버리기
train_x = train_x.loc[:, (train_x != 0).any(axis=0)]
train_x

# 테스트셋에 적용
cols = train_x.loc[:, (train_x != 0).any(axis=0)].columns
test_x = test_x[cols]

# %%
bool_cols = train_x.select_dtypes(include=['bool']).columns
bool_cols

# bool type 숫자로 변환
train_x[bool_cols] = train_x[bool_cols].astype(int)
test_x[bool_cols] = test_x[bool_cols].astype(int)

# drop
# train_x = train_x.drop(columns=bool_cols)
# test_x = test_x.drop(columns=bool_cols)

# %%
# float_cols = train_x.select_dtypes(include=['float64']).columns

# train_x[float_cols] = train_x[float_cols].astype(int)
# test_x[float_cols] = test_x[float_cols].astype(int)
# train_x.info()

# %% [markdown]
# ## 알파벳 기준으로 평균화

# %%
# train_group = train_x.groupby(train_x.columns.str[0], axis=1)
# train_mean = train_group.mean()

# test_group = test_x.groupby(test_x.columns.str[0], axis=1)
# test_mean = test_group.mean()

# train_mean

# %% [markdown]
# ## 분위수로 범주화

# %%
# # 테스트셋
# for col in train_mean.columns:
#     quantile = train_mean[col].quantile([0,0.2,0.4,0.6,0.8,1])
#     label = [1,2,3,4,5]
#     train_mean[col] = pd.cut(train_mean[col], bins=quantile.values, labels=label, include_lowest=True)

# train_mean = train_mean.astype(int)
# train_mean

# %%
# # 테스트셋
# for col in test_mean.columns:
#     quantile = test_mean[col].quantile([0,0.2,0.4,0.6,0.8,1])
#     label = [1,2,3,4,5]
#     test_mean[col] = pd.cut(test_mean[col], bins=quantile.values, labels=label, include_lowest=True)

# test_mean = test_mean.astype(int)
# test_mean

# %%
# len(train_mean.columns) , len(test_mean.columns)
# Out:
# (28, 28)

# %% [markdown]
# ## 합치기

# %%
train_df = pd.concat([train_df, train_x], axis=1)
test_df = pd.concat([test_df, test_x], axis=1)
train_df
# Out:
#               id                                             SMILES      MLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.0100  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.2700
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.5860
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.7100
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.2700
# ...          ...                                                ...      ...
# 3449  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  28.4630
# 3450  TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  56.0435
# 3451  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  56.3130
# 3452  TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  70.2150
# 3453  TRAIN_2134  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...   6.1730
#
#           HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     50.6800  3.259           400.495                5             2  \
# 1     50.5900  2.169           301.407                2             1
# 2     80.8920  1.593           297.358                5             0
# 3      2.0000  4.771           494.652                6             0
# 4     99.9900  2.335           268.310                3             0
# ...       ...    ...               ...              ...           ...
# 3449  24.1955  4.609           340.381                4             1
# 3450  66.1260  4.282           553.480                5             0
# 3451  63.7320  4.304           459.520                6             1
# 3452  93.8400 -1.133           385.417                7             0
# 3453  10.8670  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  ...      SRW10     TSRW10          MW
# 0                      8  3.259  ...  10.081676  78.761075  400.156912  \
# 1                      2  2.172  ...   9.907828  69.149596  301.124883
# 2                      3  1.585  ...  10.144510  70.158066  297.170194
# 3                      5  3.475  ...  10.613467  86.199585  494.246395
# 4                      1  2.337  ...   9.978363  53.872357  268.121178
# ...                  ...    ...  ...        ...        ...         ...
# 3449                   2  4.736  ...  10.593756  88.164476  552.169496
# 3450                   7  4.009  ...  10.677177  84.226168  459.136511
# 3451                   4  4.304  ...  10.177818  79.094663  385.175004
# 3452                   4 -1.133  ...  10.410937  83.783308  466.102099
# 3453                   8  5.630  ...        NaN        NaN         NaN
#
#            AMW   WPath  WPol  Zagreb1  Zagreb2   mZagreb1  mZagreb2
# 0     7.695325  2380.0  40.0    142.0    165.0   9.500000  6.361111
# 1     7.528122   870.0  35.0    112.0    132.0   7.138889  4.527778
# 2     7.248054  1028.0  36.0    120.0    145.0   5.277778  4.888889
# 3     7.162991  4170.0  61.0    192.0    231.0  10.784722  7.500000
# 4     7.447810   762.0  32.0    106.0    125.0   6.277778  4.361111
# ...        ...     ...   ...      ...      ...        ...       ...
# 3449  8.120140  4874.0  63.0    204.0    242.0  12.055556  8.222222
# 3450  8.502528  2888.0  61.0    186.0    227.0  10.895833  6.944444
# 3451  7.552451  2262.0  42.0    148.0    175.0   8.000000  6.222222
# 3452  8.631520  3644.0  49.0    170.0    200.0   9.791667  6.916667
# 3453       NaN     NaN   NaN      NaN      NaN        NaN       NaN
#
# [3454 rows x 1383 columns]

# %%
# train_df = pd.concat([train_df, train_x[bool_cols], train_mean], axis=1)
# test_df = pd.concat([test_df, test_x[bool_cols], test_mean], axis=1)
# train_df

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Columns: 1383 entries, id to mZagreb2
# dtypes: float64(1378), int64(3), object(2)
# memory usage: 36.4+ MB

# %%
train_df = train_df.fillna(0)
test_df = test_df.fillna(0)

train_df.isnull().sum().sum() , test_df.isnull().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# # 정답 제거

# %%
train_df = train_df.drop(columns='MLM')
# train_df = train_df.drop(columns='HLM')
train_df
# Out:
#               id                                             SMILES      HLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  50.6800  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  50.5900
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1  80.8920
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   2.0000
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  99.9900
# ...          ...                                                ...      ...
# 3449  TRAIN_1833    Cc1ccc(-c2cc(-c3nc4c5ccccc5ncn4n3)[nH]n2)c(C)c1  24.1955
# 3450  TRAIN_0898  Cc1ccc(-c2ccc(C(CN3CCCC3)N(C)C(=O)CN3C(=O)COc4...  66.1260
# 3451  TRAIN_2575  Cc1ccccc1-c1nc2ccccc2cc1C(C)n1c(=O)[nH]c2c(S(C...  63.7320
# 3452  TRAIN_0216    N#Cc1nccnc1OC1CCN(C(=O)C2CC(=O)N(C3CCOCC3)C2)C1  93.8400
# 3453  TRAIN_2134  O=S(=O)(c1ccccc1)n1ccc(C/C=C/Cc2ccn(S(=O)(=O)c...  10.8670
#
#       AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     3.259           400.495                5             2  \
# 1     2.169           301.407                2             1
# 2     1.593           297.358                5             0
# 3     4.771           494.652                6             0
# 4     2.335           268.310                3             0
# ...     ...               ...              ...           ...
# 3449  4.609           340.381                4             1
# 3450  4.282           553.480                5             0
# 3451  4.304           459.520                6             1
# 3452 -1.133           385.417                7             0
# 3453  5.630           466.572                4             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea  ...      SRW10
# 0                      8  3.259                      117.37  ...  10.081676  \
# 1                      2  2.172                       73.47  ...   9.907828
# 2                      3  1.585                       62.45  ...  10.144510
# 3                      5  3.475                       92.60  ...  10.613467
# 4                      1  2.337                       42.43  ...   9.978363
# ...                  ...    ...                         ...  ...        ...
# 3449                   2  4.736                       71.75  ...  10.593756
# 3450                   7  4.009                       65.98  ...  10.677177
# 3451                   4  4.304                      113.53  ...  10.177818
# 3452                   4 -1.133                      108.65  ...  10.410937
# 3453                   8  5.630                       94.90  ...   0.000000
#
#          TSRW10          MW       AMW   WPath  WPol  Zagreb1  Zagreb2
# 0     78.761075  400.156912  7.695325  2380.0  40.0    142.0    165.0  \
# 1     69.149596  301.124883  7.528122   870.0  35.0    112.0    132.0
# 2     70.158066  297.170194  7.248054  1028.0  36.0    120.0    145.0
# 3     86.199585  494.246395  7.162991  4170.0  61.0    192.0    231.0
# 4     53.872357  268.121178  7.447810   762.0  32.0    106.0    125.0
# ...         ...         ...       ...     ...   ...      ...      ...
# 3449  88.164476  552.169496  8.120140  4874.0  63.0    204.0    242.0
# 3450  84.226168  459.136511  8.502528  2888.0  61.0    186.0    227.0
# 3451  79.094663  385.175004  7.552451  2262.0  42.0    148.0    175.0
# 3452  83.783308  466.102099  8.631520  3644.0  49.0    170.0    200.0
# 3453   0.000000    0.000000  0.000000     0.0   0.0      0.0      0.0
#
#        mZagreb1  mZagreb2
# 0      9.500000  6.361111
# 1      7.138889  4.527778
# 2      5.277778  4.888889
# 3     10.784722  7.500000
# 4      6.277778  4.361111
# ...         ...       ...
# 3449  12.055556  8.222222
# 3450  10.895833  6.944444
# 3451   8.000000  6.222222
# 3452   9.791667  6.916667
# 3453   0.000000  0.000000
#
# [3454 rows x 1382 columns]

# %%
test_df
# Out:
#            id                                             SMILES  AlogP
# 0    TEST_000            CC(C)Nc1ccnc(N2CCN(Cc3cccs3)C(CCO)C2)n1  2.641  \
# 1    TEST_001     COc1cc(=O)n(-c2ccccc2)cc1C(=O)N1CCC2(CC1)OCCO2  0.585
# 2    TEST_002  Cc1cccc(NC(=N)/N=c2\nc(O)c(Cc3ccccc3)c(C)[nH]2)c1  4.276
# 3    TEST_003         O=C(c1nc2ncccn2n1)N1CCCn2cc(-c3ccccc3)nc21  1.795
# 4    TEST_004       CCN1CCN(C(=O)c2cc3c(=O)n4cc(C)ccc4nc3n2C)CC1  1.219
# ..        ...                                                ...    ...
# 478  TEST_478                  CCc1noc(CC)c1CC(=O)NCC1(CC)CCCCC1  4.207
# 479  TEST_479     CC(=O)N1CCC2(CC1)OC(=O)C(C)=C2C(=O)N1CCN(C)CC1 -0.608
# 480  TEST_480      CC(C)NC(=O)CN1C(=O)c2ccccc2N2C(=O)c3ccccc3C12  1.792
# 481  TEST_481              Cn1cc(Br)c(=O)c(NC(=O)c2ccc(O)cc2F)c1  0.790
# 482  TEST_482                       CC(C)C(CCN1CCN(C)CC1)c1ccco1  2.782
#
#      Molecular_Weight  Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds
# 0             361.505                4             2                   7  \
# 1             370.399                5             0                   3
# 2             347.414                4             4                   5
# 3             345.358                5             0                   2
# 4             353.418                4             0                   2
# ..                ...              ...           ...                 ...
# 478           306.443                2             1                   7
# 479           335.398                5             0                   1
# 480           349.383                3             1                   3
# 481           341.132                3             2                   2
# 482           250.380                2             0                   5
#
#       LogD  Molecular_PolarSurfaceArea  nAcid  ...      SRW10     TSRW10
# 0    2.635                       92.76      0  ...   9.935713  72.422574  \
# 1    0.585                       68.31      0  ...  10.330421  76.111616
# 2    4.290                       92.86      0  ...  10.008163  60.614034
# 3    1.795                       81.21      0  ...  10.288444  77.464779
# 4    0.169                       61.15      0  ...  10.380312  75.874629
# ..     ...                         ...    ...  ...        ...        ...
# 478  4.207                       55.13      0  ...   9.862509  69.656439
# 479 -1.736                       70.16      0  ...  10.288852  73.647870
# 480  1.792                       69.72      0  ...  10.447235  76.277596
# 481  0.423                       69.64      0  ...   9.874728  53.565348
# 482  0.606                       19.62      0  ...   9.478763  63.502070
#
#              MW        AMW  WPath  WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 0    361.193631   6.946031   1607    34    126.0    144.0  7.527778  5.638889
# 1    370.152872   7.554140   1853    45    146.0    175.0  7.840278  5.972222
# 2    347.174610   7.386694   1905    37    132.0    150.0  8.388889  5.722222
# 3    345.133808   8.417898   1673    42    146.0    177.0  6.000000  5.583333
# 4    353.185175   7.207861   1656    47    144.0    176.0  8.722222  5.638889
# ..          ...        ...    ...   ...      ...      ...       ...       ...
# 478  306.230728   5.889052   1138    32    108.0    125.0  7.756944  5.222222
# 479  335.184506   6.840500   1280    42    130.0    157.0  9.201389  5.180556
# 480  349.142641   7.758725   1469    48    144.0    177.0  8.722222  5.611111
# 481  339.985883  11.332863    826    31    102.0    118.0  8.388889  4.361111
# 482  250.204513   5.686466    660    22     88.0     99.0  6.055556  4.055556
#
# [483 rows x 1381 columns]

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\python39\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\python39\lib\site-packages (from imblearn) (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\python39\lib\site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\python39\lib\site-packages (from imbalanced-learn->imblearn) (1.8.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\python39\lib\site-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\python39\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python39\lib\site-packages (from imbalanced-learn->imblearn) (3.1.0)

# %% [markdown]
# # 오버샘플링

# %%
from imblearn.combine import SMOTEENN

def smoteenn_combine(df):
    X = df.iloc[:,3:]
    y = df['HLM'].astype(int) # 연속형 -> 이산형
    num_resampled = round(train_df.shape[0] / 2) # 절반
    smoteenn = SMOTEENN(sampling_strategy={1:num_resampled}, random_state=SEED)
    # smoteenn = SMOTEENN(sampling_strategy='auto', random_state=SEED)
    X_resampled, y_resampled = smoteenn.fit_resample(X, y)

    X_df = pd.DataFrame(X_resampled, columns=X.columns)
    y_df = pd.DataFrame({'HLM': y_resampled})

    return X_df, y_df

X_resampled, y_resampled = smoteenn_combine(train_df)

# %%
train_over = pd.concat([y_resampled,X_resampled],axis=1)
train_df = pd.concat([train_df,train_over],axis=0).reset_index(drop=True)
train_df
# Out:
#               id                                             SMILES     HLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  50.680  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  50.590
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1  80.892
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   2.000
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  99.990
# ...          ...                                                ...     ...
# 5121         NaN                                                NaN   1.000
# 5122         NaN                                                NaN   1.000
# 5123         NaN                                                NaN   1.000
# 5124         NaN                                                NaN   1.000
# 5125         NaN                                                NaN  99.000
#
#          AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     3.259000        400.495000                5             2  \
# 1     2.169000        301.407000                2             1
# 2     1.593000        297.358000                5             0
# 3     4.771000        494.652000                6             0
# 4     2.335000        268.310000                3             0
# ...        ...               ...              ...           ...
# 5121  5.504180        356.513032                1             1
# 5122  2.807432        305.823987                3             2
# 5123  2.593721        421.734633                4             0
# 5124  4.907092        409.950748                2             1
# 5125 -1.480000        318.328000                5             1
#
#       Num_RotatableBonds      LogD  Molecular_PolarSurfaceArea  ...
# 0                      8  3.259000                  117.370000  ...  \
# 1                      2  2.172000                   73.470000  ...
# 2                      3  1.585000                   62.450000  ...
# 3                      5  3.475000                   92.600000  ...
# 4                      1  2.337000                   42.430000  ...
# ...                  ...       ...                         ...  ...
# 5121                   1  5.500909                   63.807279  ...
# 5122                   4  2.789527                   78.567795  ...
# 5123                   5  2.593721                   98.646677  ...
# 5124                   3  4.907092                   74.737248  ...
# 5125                   6 -1.480000                   91.310000  ...
#
#           SRW10     TSRW10          MW       AMW        WPath       WPol
# 0     10.081676  78.761075  400.156912  7.695325  2380.000000  40.000000  \
# 1      9.907828  69.149596  301.124883  7.528122   870.000000  35.000000
# 2     10.144510  70.158066  297.170194  7.248054  1028.000000  36.000000
# 3     10.613467  86.199585  494.246395  7.162991  4170.000000  61.000000
# 4      9.978363  53.872357  268.121178  7.447810   762.000000  32.000000
# ...         ...        ...         ...       ...          ...        ...
# 5121   9.980158  60.762847  284.560344  9.118289   857.560833  31.364521
# 5122   9.888118  66.340703  305.564353  9.170210  1047.224708  30.510913
# 5123  10.364220  86.626182  471.242533  7.014172  4332.349864  51.336871
# 5124  10.362463  78.629958  409.587723  7.233960  2232.394292  51.535513
# 5125   9.865214  56.832561  318.132805  7.759337  1380.000000  34.000000
#
#          Zagreb1     Zagreb2   mZagreb1  mZagreb2
# 0     142.000000  165.000000   9.500000  6.361111
# 1     112.000000  132.000000   7.138889  4.527778
# 2     120.000000  145.000000   5.277778  4.888889
# 3     192.000000  231.000000  10.784722  7.500000
# 4     106.000000  125.000000   6.277778  4.361111
# ...          ...         ...        ...       ...
# 5121  109.182261  129.817739   5.710038  4.372604
# 5122  110.277282  125.974331   9.092623  4.573599
# 5123  182.010612  214.026530  10.008326  7.499263
# 5124  158.171631  191.417205   8.674246  6.356222
# 5125  112.000000  128.000000   8.527778  5.277778
#
# [5126 rows x 1382 columns]

# %% [markdown]
# # 언더샘플링

# %%
# from imblearn.under_sampling import RandomUnderSampler

# def random_undersample(df):
#     X = df.iloc[:,3:]
#     y = df['HLM'].astype(int) # 연속형 -> 이산형

#     # sampler = RandomUnderSampler(sampling_strategy='auto', random_state=SEED)
#     sampler = RandomUnderSampler(sampling_strategy='majority', random_state=SEED) # 많은 클래스의 샘플은 모두 유지, 적은 클래스의 샘플은 일부만 유지
#     X_resampled, y_resampled = sampler.fit_resample(X, y)

#     X_df = pd.DataFrame(X_resampled, columns=X.columns)
#     y_df = pd.DataFrame({'HLM': y_resampled})

#     return X_resampled, y_resampled

# # 사용 예시
# X_resampled, y_resampled = random_undersample(train_df)
# X_resampled.shape

# %%
# train_under = pd.concat([y_resampled,X_resampled],axis=1)
# train_under

# %%
# # 정답값 실제데이터로 반영(이산형으로 바꾸려고 정수로 변환했어가지고)
# train_under['HLM'] = train_df['HLM']
# train_under

# %%
# train_under.isnull().sum().sum()

# %% [markdown]
# # Scaling

# %%
train_df.iloc[:,3:].columns
# Out:
# Index(['AlogP', 'Molecular_Weight', 'Num_H_Acceptors', 'Num_H_Donors',
#        'Num_RotatableBonds', 'LogD', 'Molecular_PolarSurfaceArea', 'nAcid',
#        'nBase', 'SpAbs_A',
#        ...
#        'SRW10', 'TSRW10', 'MW', 'AMW', 'WPath', 'WPol', 'Zagreb1', 'Zagreb2',
#        'mZagreb1', 'mZagreb2'],
#       dtype='object', length=1379)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train_cols = train_df.iloc[:,3:].columns
# train_cols = train_under.iloc[:,1:].columns # 언더샘플링된 학습데이터
test_cols = test_df.iloc[:,2:].columns

train_df[train_cols] = scaler.fit_transform(train_df[train_cols])
# train_under[train_cols] = scaler.fit_transform(train_under[train_cols]) # 언더샘플링된 학습데이터
test_df[test_cols] = scaler.transform(test_df[test_cols])

test_df
# Out:
#            id                                             SMILES     AlogP
# 0    TEST_000            CC(C)Nc1ccnc(N2CCN(Cc3cccs3)C(CCO)C2)n1  0.435626  \
# 1    TEST_001     COc1cc(=O)n(-c2ccccc2)cc1C(=O)N1CCC2(CC1)OCCO2  0.258445
# 2    TEST_002  Cc1cccc(NC(=N)/N=c2\nc(O)c(Cc3ccccc3)c(C)[nH]2)c1  0.576525
# 3    TEST_003         O=C(c1nc2ncccn2n1)N1CCCn2cc(-c3ccccc3)nc21  0.362720
# 4    TEST_004       CCN1CCN(C(=O)c2cc3c(=O)n4cc(C)ccc4nc3n2C)CC1  0.313082
# ..        ...                                                ...       ...
# 478  TEST_478                  CCc1noc(CC)c1CC(=O)NCC1(CC)CCCCC1  0.570579
# 479  TEST_479     CC(=O)N1CCC2(CC1)OC(=O)C(C)=C2C(=O)N1CCN(C)CC1  0.155636
# 480  TEST_480      CC(C)NC(=O)CN1C(=O)c2ccccc2N2C(=O)c3ccccc3C12  0.362461
# 481  TEST_481              Cn1cc(Br)c(=O)c(NC(=O)c2ccc(O)cc2F)c1  0.276112
# 482  TEST_482                       CC(C)C(CCN1CCN(C)CC1)c1ccco1  0.447777
#
#      Molecular_Weight  Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds
# 0            0.338954         0.333333         0.250            0.411765  \
# 1            0.354877         0.416667         0.000            0.176471
# 2            0.313726         0.333333         0.500            0.294118
# 3            0.310045         0.416667         0.000            0.117647
# 4            0.324475         0.333333         0.000            0.117647
# ..                ...              ...           ...                 ...
# 478          0.240375         0.166667         0.125            0.411765
# 479          0.292214         0.416667         0.000            0.058824
# 480          0.317251         0.250000         0.125            0.176471
# 481          0.302479         0.250000         0.250            0.117647
# 482          0.140004         0.166667         0.000            0.294118
#
#          LogD  Molecular_PolarSurfaceArea  nAcid  ...     SRW10    TSRW10
# 0    0.476103                    0.428921    0.0  ...  0.869813  0.676470  \
# 1    0.312260                    0.311772    0.0  ...  0.904367  0.710928
# 2    0.608376                    0.429400    0.0  ...  0.876156  0.566171
# 3    0.408967                    0.373581    0.0  ...  0.900693  0.723568
# 4    0.279012                    0.277466    0.0  ...  0.908735  0.708715
# ..        ...                         ...    ...  ...       ...       ...
# 478  0.601742                    0.248622    0.0  ...  0.863404  0.650633
# 479  0.126758                    0.320636    0.0  ...  0.900728  0.687915
# 480  0.408728                    0.318528    0.0  ...  0.914594  0.712479
# 481  0.299313                    0.318145    0.0  ...  0.864474  0.500333
# 482  0.313939                    0.078482    0.0  ...  0.829810  0.593147
#
#            MW       AMW     WPath      WPol   Zagreb1   Zagreb2  mZagreb1
# 0    0.494571  0.317098  0.150440  0.320755  0.420000  0.384000  0.339812  \
# 1    0.506839  0.344860  0.173469  0.424528  0.486667  0.466667  0.353918
# 2    0.475376  0.337215  0.178337  0.349057  0.440000  0.400000  0.378683
# 3    0.472581  0.384292  0.156619  0.396226  0.486667  0.472000  0.270846
# 4    0.483606  0.329051  0.155027  0.443396  0.480000  0.469333  0.393730
# ..        ...       ...       ...       ...       ...       ...       ...
# 478  0.419312  0.268845  0.106534  0.301887  0.360000  0.333333  0.350157
# 479  0.458958  0.312281  0.119828  0.396226  0.433333  0.418667  0.415361
# 480  0.478070  0.354199  0.137521  0.452830  0.480000  0.472000  0.393730
# 481  0.465532  0.517365  0.077326  0.292453  0.340000  0.314667  0.378683
# 482  0.342597  0.259597  0.061786  0.207547  0.293333  0.264000  0.273354
#
#      mZagreb2
# 0    0.506866
# 1    0.536829
# 2    0.514357
# 3    0.501873
# 4    0.506866
# ..        ...
# 478  0.469413
# 479  0.465668
# 480  0.504370
# 481  0.392010
# 482  0.364544
#
# [483 rows x 1381 columns]

# %%
train_df
# Out:
#               id                                             SMILES     HLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  50.680  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  50.590
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1  80.892
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   2.000
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  99.990
# ...          ...                                                ...     ...
# 5121         NaN                                                NaN   1.000
# 5122         NaN                                                NaN   1.000
# 5123         NaN                                                NaN   1.000
# 5124         NaN                                                NaN   1.000
# 5125         NaN                                                NaN  99.000
#
#          AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     0.488883          0.408759         0.416667         0.250  \
# 1     0.394950          0.231359         0.166667         0.125
# 2     0.345312          0.224110         0.416667         0.000
# 3     0.619183          0.577331         0.500000         0.000
# 4     0.409255          0.172104         0.250000         0.000
# ...        ...               ...              ...           ...
# 5121  0.682366          0.330017         0.083333         0.125
# 5122  0.449968          0.239267         0.250000         0.250
# 5123  0.431551          0.446785         0.333333         0.000
# 5124  0.630911          0.425688         0.166667         0.125
# 5125  0.080489          0.261653         0.416667         0.125
#
#       Num_RotatableBonds      LogD  Molecular_PolarSurfaceArea  ...     SRW10
# 0               0.470588  0.525975                    0.546835  ...  0.882591  \
# 1               0.117647  0.439098                    0.336496  ...  0.867372
# 2               0.176471  0.392184                    0.283695  ...  0.888092
# 3               0.294118  0.543238                    0.428154  ...  0.929146
# 4               0.058824  0.452286                    0.187773  ...  0.873547
# ...                  ...       ...                         ...  ...       ...
# 5121            0.058824  0.705156                    0.290198  ...  0.873704
# 5122            0.235294  0.488453                    0.360921  ...  0.865646
# 5123            0.294118  0.472804                    0.457126  ...  0.907326
# 5124            0.176471  0.657696                    0.342567  ...  0.907172
# 5125            0.352941  0.147219                    0.421973  ...  0.863641
#
#         TSRW10        MW       AMW     WPath      WPol   Zagreb1   Zagreb2
# 0     0.735676  0.547923  0.351305  0.222805  0.377358  0.473333  0.440000  \
# 1     0.645899  0.412321  0.343672  0.081445  0.330189  0.373333  0.352000
# 2     0.655318  0.406906  0.330886  0.096237  0.339623  0.400000  0.386667
# 3     0.805156  0.676756  0.327003  0.390376  0.575472  0.640000  0.616000
# 4     0.503200  0.367130  0.340005  0.071335  0.301887  0.353333  0.333333
# ...        ...       ...       ...       ...       ...       ...       ...
# 5121  0.567561  0.389640  0.416266  0.080281  0.295892  0.363941  0.346181
# 5122  0.619662  0.418400  0.418636  0.098036  0.287839  0.367591  0.335932
# 5123  0.809141  0.645258  0.320209  0.405575  0.484310  0.606702  0.570737
# 5124  0.734451  0.560836  0.330243  0.208987  0.486184  0.527239  0.510446
# 5125  0.530850  0.435609  0.354227  0.129189  0.320755  0.373333  0.341333
#
#       mZagreb1  mZagreb2
# 0     0.428840  0.571785
# 1     0.322257  0.406991
# 2     0.238245  0.439451
# 3     0.486834  0.674157
# 4     0.283386  0.392010
# ...        ...       ...
# 5121  0.257757  0.393043
# 5122  0.410451  0.411110
# 5123  0.451786  0.674091
# 5124  0.391565  0.571346
# 5125  0.384953  0.474407
#
# [5126 rows x 1382 columns]

# %%
train_df.to_csv(f"{DATA_PATH}train_clean_mor_scale_15.csv", index=False)
# train_under.to_csv(f"{DATA_PATH}train_clean_mor_scale_8.csv", index=False)
test_df.to_csv(f"{DATA_PATH}test_clean_mor_scale_15.csv", index=False)

# %%
train_df = pd.read_csv(f'{DATA_PATH}train_clean_mor_scale_15.csv')
test_df = pd.read_csv(f'{DATA_PATH}test_clean_mor_scale_15.csv')
train_df
# Out:
#               id                                             SMILES     HLM
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  50.680  \
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  50.590
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1  80.892
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   2.000
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  99.990
# ...          ...                                                ...     ...
# 5121         NaN                                                NaN   1.000
# 5122         NaN                                                NaN   1.000
# 5123         NaN                                                NaN   1.000
# 5124         NaN                                                NaN   1.000
# 5125         NaN                                                NaN  99.000
#
#          AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors
# 0     0.488883          0.408759         0.416667         0.250  \
# 1     0.394950          0.231359         0.166667         0.125
# 2     0.345312          0.224110         0.416667         0.000
# 3     0.619183          0.577331         0.500000         0.000
# 4     0.409255          0.172104         0.250000         0.000
# ...        ...               ...              ...           ...
# 5121  0.682366          0.330017         0.083333         0.125
# 5122  0.449968          0.239267         0.250000         0.250
# 5123  0.431551          0.446785         0.333333         0.000
# 5124  0.630911          0.425688         0.166667         0.125
# 5125  0.080489          0.261653         0.416667         0.125
#
#       Num_RotatableBonds      LogD  Molecular_PolarSurfaceArea  ...     SRW10
# 0               0.470588  0.525975                    0.546835  ...  0.882591  \
# 1               0.117647  0.439098                    0.336496  ...  0.867372
# 2               0.176471  0.392184                    0.283695  ...  0.888092
# 3               0.294118  0.543238                    0.428154  ...  0.929146
# 4               0.058824  0.452286                    0.187773  ...  0.873547
# ...                  ...       ...                         ...  ...       ...
# 5121            0.058824  0.705156                    0.290198  ...  0.873704
# 5122            0.235294  0.488453                    0.360921  ...  0.865646
# 5123            0.294118  0.472804                    0.457126  ...  0.907326
# 5124            0.176471  0.657696                    0.342567  ...  0.907172
# 5125            0.352941  0.147219                    0.421973  ...  0.863641
#
#         TSRW10        MW       AMW     WPath      WPol   Zagreb1   Zagreb2
# 0     0.735676  0.547923  0.351305  0.222805  0.377358  0.473333  0.440000  \
# 1     0.645899  0.412321  0.343672  0.081445  0.330189  0.373333  0.352000
# 2     0.655318  0.406906  0.330886  0.096237  0.339623  0.400000  0.386667
# 3     0.805156  0.676756  0.327003  0.390376  0.575472  0.640000  0.616000
# 4     0.503200  0.367130  0.340005  0.071335  0.301887  0.353333  0.333333
# ...        ...       ...       ...       ...       ...       ...       ...
# 5121  0.567561  0.389640  0.416266  0.080281  0.295892  0.363941  0.346181
# 5122  0.619662  0.418400  0.418636  0.098036  0.287839  0.367591  0.335932
# 5123  0.809141  0.645258  0.320209  0.405575  0.484310  0.606702  0.570737
# 5124  0.734451  0.560836  0.330243  0.208987  0.486184  0.527239  0.510446
# 5125  0.530850  0.435609  0.354227  0.129189  0.320755  0.373333  0.341333
#
#       mZagreb1  mZagreb2
# 0     0.428840  0.571785
# 1     0.322257  0.406991
# 2     0.238245  0.439451
# 3     0.486834  0.674157
# 4     0.283386  0.392010
# ...        ...       ...
# 5121  0.257757  0.393043
# 5122  0.410451  0.411110
# 5123  0.451786  0.674091
# 5124  0.391565  0.571346
# 5125  0.384953  0.474407
#
# [5126 rows x 1382 columns]

# %% [markdown]
# # Auto Modeling

# %%
from flaml import AutoML
model = AutoML()
params = {
    "metric": "rmse",
    "task": "regression",
    "time_budget": 60*60*4,
    "seed": SEED,
    "early_stop": False,
    "ensemble" : True,
    # "estimator_list": ['lgbm']
    "estimator_list": ['lgbm', 'xgboost', 'rf', 'catboost']
}

model.fit(train_df.iloc[:,3:], train_df['HLM'], **params)
# model.fit(train_df.iloc[:,1:], train_df['HLM'], **params)
pred = model.predict(test_df.iloc[:,2:])
print(model.best_config)
print(model.best_loss)
# Out:
# [flaml.automl.logger: 09-24 23:37:37] {1679} INFO - task = regression
# [flaml.automl.logger: 09-24 23:37:37] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 09-24 23:37:37] {1788} INFO - Minimizing error metric: rmse
# [flaml.automl.logger: 09-24 23:37:37] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'xgboost', 'rf', 'catboost']
# [flaml.automl.logger: 09-24 23:37:37] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 09-24 23:37:44] {2344} INFO - Estimated sufficient time budget=66413s. Estimated necessary time budget=130s.
# [flaml.automl.logger: 09-24 23:37:44] {2391} INFO -  at 9.7s,	estimator lgbm's best error=35.2172,	best estimator lgbm's best error=35.2172
# [flaml.automl.logger: 09-24 23:37:44] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 09-24 23:37:51] {2391} INFO -  at 16.3s,	estimator lgbm's best error=35.2172,	best estimator lgbm's best error=35.2172
# [flaml.automl.logger: 09-24 23:37:51] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 09-24 23:37:56] {2391} INFO -  at 21.3s,	estimator lgbm's best error=33.3052,	best estimator lgbm's best error=33.3052
# [flaml.automl.logger: 09-24 23:37:56] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 09-24 23:38:03] {2391} INFO -  at 28.5s,	estimator xgboost's best error=42.2526,	best estimator lgbm's best error=33.3052
# [flaml.automl.logger: 09-24 23:38:03] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 09-24 23:38:08] {2391} INFO -  at 33.7s,	estimator lgbm's best error=29.8901,	best estimator lgbm's best error=29.8901
# [flaml.automl.logger: 09-24 23:38:08] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 09-24 23:38:15] {2391} INFO -  at 40.9s,	estimator lgbm's best error=29.8901,	best estimator lgbm's best error=29.8901
# [flaml.automl.logger: 09-24 23:38:15] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 09-24 23:38:22] {2391} INFO -  at 47.3s,	estimator lgbm's best error=29.3952,	best estimator lgbm's best error=29.3952
# [flaml.automl.logger: 09-24 23:38:22] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 09-24 23:38:30] {2391} INFO -  at 55.3s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:38:30] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 09-24 23:38:35] {2391} INFO -  at 61.2s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:38:35] {2218} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 09-24 23:38:41] {2391} INFO -  at 67.1s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:38:41] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 09-24 23:38:48] {2391} INFO -  at 73.3s,	estimator xgboost's best error=42.2526,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:38:48] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 09-24 23:38:54] {2391} INFO -  at 80.0s,	estimator xgboost's best error=38.3405,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:38:54] {2218} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 09-24 23:39:02] {2391} INFO -  at 87.9s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:39:02] {2218} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 09-24 23:39:09] {2391} INFO -  at 94.3s,	estimator xgboost's best error=38.3405,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:39:09] {2218} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 09-24 23:39:21] {2391} INFO -  at 107.1s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:39:21] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 09-24 23:39:30] {2391} INFO -  at 115.5s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:39:30] {2218} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 09-24 23:39:44] {2391} INFO -  at 130.2s,	estimator rf's best error=32.3055,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:39:44] {2218} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 09-24 23:39:50] {2391} INFO -  at 135.5s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:39:50] {2218} INFO - iteration 18, current learner rf
# [flaml.automl.logger: 09-24 23:40:02] {2391} INFO -  at 147.5s,	estimator rf's best error=32.3055,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:40:02] {2218} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 09-24 23:40:08] {2391} INFO -  at 153.8s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:40:08] {2218} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 09-24 23:40:26] {2391} INFO -  at 172.2s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:40:26] {2218} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 09-24 23:40:32] {2391} INFO -  at 177.4s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:40:32] {2218} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 09-24 23:40:44] {2391} INFO -  at 189.8s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:40:44] {2218} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 09-24 23:41:08] {2391} INFO -  at 213.4s,	estimator rf's best error=31.4893,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:41:08] {2218} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 09-24 23:41:31] {2391} INFO -  at 236.4s,	estimator rf's best error=30.9008,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:41:31] {2218} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 09-24 23:41:38] {2391} INFO -  at 243.7s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:41:38] {2218} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 09-24 23:42:47] {2391} INFO -  at 312.8s,	estimator rf's best error=29.9184,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:42:47] {2218} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 09-24 23:43:11] {2391} INFO -  at 336.5s,	estimator rf's best error=29.9184,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:43:11] {2218} INFO - iteration 28, current learner rf
# [flaml.automl.logger: 09-24 23:43:45] {2391} INFO -  at 371.2s,	estimator rf's best error=29.7428,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:43:45] {2218} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 09-24 23:43:55] {2391} INFO -  at 380.9s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:43:55] {2218} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 09-24 23:44:16] {2391} INFO -  at 401.8s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:44:16] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 09-24 23:44:21] {2391} INFO -  at 407.0s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:44:21] {2218} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 09-24 23:45:15] {2391} INFO -  at 460.6s,	estimator rf's best error=29.7428,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:45:15] {2218} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 09-24 23:45:20] {2391} INFO -  at 466.1s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:45:20] {2218} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 09-24 23:45:30] {2391} INFO -  at 475.8s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:45:30] {2218} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 09-24 23:46:02] {2391} INFO -  at 507.5s,	estimator rf's best error=29.7428,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:46:02] {2218} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 09-24 23:46:11] {2391} INFO -  at 517.1s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:46:11] {2218} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 09-24 23:46:18] {2391} INFO -  at 523.5s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:46:18] {2218} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 09-24 23:46:31] {2391} INFO -  at 536.6s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:46:31] {2218} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 09-24 23:47:29] {2391} INFO -  at 594.6s,	estimator rf's best error=29.4609,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:47:29] {2218} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 09-24 23:48:26] {2391} INFO -  at 651.6s,	estimator rf's best error=29.4609,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:48:26] {2218} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 09-24 23:48:43] {2391} INFO -  at 669.1s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:48:43] {2218} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 09-24 23:48:52] {2391} INFO -  at 677.7s,	estimator xgboost's best error=29.4754,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:48:52] {2218} INFO - iteration 43, current learner rf
# [flaml.automl.logger: 09-24 23:49:38] {2391} INFO -  at 724.2s,	estimator rf's best error=29.0025,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:49:38] {2218} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 09-24 23:50:00] {2391} INFO -  at 745.4s,	estimator rf's best error=29.0025,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:50:00] {2218} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 09-24 23:50:11] {2391} INFO -  at 756.8s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:50:11] {2218} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 09-24 23:52:32] {2391} INFO -  at 897.6s,	estimator rf's best error=28.8390,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:52:32] {2218} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 09-24 23:52:37] {2391} INFO -  at 902.4s,	estimator lgbm's best error=28.1785,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:52:37] {2218} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 09-24 23:52:50] {2391} INFO -  at 915.3s,	estimator xgboost's best error=28.9303,	best estimator lgbm's best error=28.1785
# [flaml.automl.logger: 09-24 23:52:50] {2218} INFO - iteration 49, current learner catboost
# [flaml.automl.logger: 09-24 23:54:29] {2391} INFO -  at 1014.9s,	estimator catboost's best error=27.8342,	best estimator catboost's best error=27.8342
# [flaml.automl.logger: 09-24 23:54:29] {2218} INFO - iteration 50, current learner catboost
# [flaml.automl.logger: 09-24 23:56:41] {2391} INFO -  at 1147.0s,	estimator catboost's best error=27.7929,	best estimator catboost's best error=27.7929
# [flaml.automl.logger: 09-24 23:56:41] {2218} INFO - iteration 51, current learner xgboost
# [flaml.automl.logger: 09-24 23:56:53] {2391} INFO -  at 1158.5s,	estimator xgboost's best error=28.9303,	best estimator catboost's best error=27.7929
# [flaml.automl.logger: 09-24 23:56:53] {2218} INFO - iteration 52, current learner xgboost
# [flaml.automl.logger: 09-24 23:57:26] {2391} INFO -  at 1192.1s,	estimator xgboost's best error=28.0227,	best estimator catboost's best error=27.7929
# [flaml.automl.logger: 09-24 23:57:26] {2218} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 09-24 23:57:34] {2391} INFO -  at 1199.8s,	estimator lgbm's best error=28.1785,	best estimator catboost's best error=27.7929
# [flaml.automl.logger: 09-24 23:57:34] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 09-24 23:57:41] {2391} INFO -  at 1206.5s,	estimator lgbm's best error=28.1785,	best estimator catboost's best error=27.7929
# [flaml.automl.logger: 09-24 23:57:41] {2218} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 09-24 23:58:52] {2391} INFO -  at 1277.6s,	estimator xgboost's best error=27.6520,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-24 23:58:52] {2218} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 09-24 23:58:57] {2391} INFO -  at 1282.4s,	estimator lgbm's best error=28.1785,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-24 23:58:57] {2218} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 09-24 23:59:29] {2391} INFO -  at 1315.2s,	estimator xgboost's best error=27.6520,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-24 23:59:29] {2218} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 09-25 00:01:29] {2391} INFO -  at 1434.5s,	estimator xgboost's best error=27.6520,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:01:29] {2218} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 09-25 00:01:41] {2391} INFO -  at 1446.5s,	estimator lgbm's best error=27.8917,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:01:41] {2218} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 09-25 00:03:55] {2391} INFO -  at 1580.7s,	estimator rf's best error=28.8390,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:03:55] {2218} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 09-25 00:04:06] {2391} INFO -  at 1591.7s,	estimator lgbm's best error=27.8917,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:04:06] {2218} INFO - iteration 62, current learner rf
# [flaml.automl.logger: 09-25 00:05:41] {2391} INFO -  at 1686.9s,	estimator rf's best error=28.7100,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:05:41] {2218} INFO - iteration 63, current learner rf
# [flaml.automl.logger: 09-25 00:08:04] {2391} INFO -  at 1829.3s,	estimator rf's best error=28.7100,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:08:04] {2218} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 09-25 00:08:16] {2391} INFO -  at 1841.9s,	estimator lgbm's best error=27.7661,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:08:16] {2218} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 09-25 00:08:25] {2391} INFO -  at 1850.9s,	estimator lgbm's best error=27.7661,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:08:25] {2218} INFO - iteration 66, current learner lgbm
# [flaml.automl.logger: 09-25 00:08:45] {2391} INFO -  at 1870.4s,	estimator lgbm's best error=27.7661,	best estimator xgboost's best error=27.6520
# [flaml.automl.logger: 09-25 00:08:45] {2218} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 09-25 00:09:08] {2391} INFO -  at 1893.5s,	estimator lgbm's best error=27.4926,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:09:08] {2218} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 09-25 00:09:21] {2391} INFO -  at 1906.7s,	estimator lgbm's best error=27.4926,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:09:21] {2218} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 09-25 00:10:08] {2391} INFO -  at 1953.7s,	estimator xgboost's best error=27.6520,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:10:08] {2218} INFO - iteration 70, current learner xgboost
# [flaml.automl.logger: 09-25 00:10:50] {2391} INFO -  at 1996.1s,	estimator xgboost's best error=27.6520,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:10:50] {2218} INFO - iteration 71, current learner lgbm
# [flaml.automl.logger: 09-25 00:11:18] {2391} INFO -  at 2023.7s,	estimator lgbm's best error=27.4926,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:11:18] {2218} INFO - iteration 72, current learner catboost
# [flaml.automl.logger: 09-25 00:14:34] {2391} INFO -  at 2219.4s,	estimator catboost's best error=27.7407,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:14:34] {2218} INFO - iteration 73, current learner lgbm
# [flaml.automl.logger: 09-25 00:14:52] {2391} INFO -  at 2237.5s,	estimator lgbm's best error=27.4926,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:14:52] {2218} INFO - iteration 74, current learner catboost
# [flaml.automl.logger: 09-25 00:17:00] {2391} INFO -  at 2365.8s,	estimator catboost's best error=27.7407,	best estimator lgbm's best error=27.4926
# [flaml.automl.logger: 09-25 00:17:00] {2218} INFO - iteration 75, current learner lgbm
# [flaml.automl.logger: 09-25 00:19:30] {2391} INFO -  at 2515.5s,	estimator lgbm's best error=27.3977,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:19:30] {2218} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 09-25 00:19:53] {2391} INFO -  at 2538.7s,	estimator lgbm's best error=27.3977,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:19:53] {2218} INFO - iteration 77, current learner catboost
# [flaml.automl.logger: 09-25 00:23:23] {2391} INFO -  at 2749.2s,	estimator catboost's best error=27.7012,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:23:23] {2218} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 09-25 00:25:00] {2391} INFO -  at 2845.7s,	estimator xgboost's best error=27.5632,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:25:00] {2218} INFO - iteration 79, current learner lgbm
# [flaml.automl.logger: 09-25 00:25:22] {2391} INFO -  at 2867.5s,	estimator lgbm's best error=27.3977,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:25:22] {2218} INFO - iteration 80, current learner catboost
# [flaml.automl.logger: 09-25 00:27:45] {2391} INFO -  at 3010.3s,	estimator catboost's best error=27.6646,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:27:45] {2218} INFO - iteration 81, current learner xgboost
# [flaml.automl.logger: 09-25 00:30:00] {2391} INFO -  at 3145.2s,	estimator xgboost's best error=27.5632,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:30:00] {2218} INFO - iteration 82, current learner catboost
# [flaml.automl.logger: 09-25 00:33:20] {2391} INFO -  at 3345.4s,	estimator catboost's best error=27.6646,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:33:20] {2218} INFO - iteration 83, current learner catboost
# [flaml.automl.logger: 09-25 00:36:32] {2391} INFO -  at 3537.3s,	estimator catboost's best error=27.4630,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:36:32] {2218} INFO - iteration 84, current learner catboost
# [flaml.automl.logger: 09-25 00:38:33] {2391} INFO -  at 3659.0s,	estimator catboost's best error=27.4630,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:38:33] {2218} INFO - iteration 85, current learner rf
# [flaml.automl.logger: 09-25 00:39:24] {2391} INFO -  at 3709.3s,	estimator rf's best error=28.5331,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:39:24] {2218} INFO - iteration 86, current learner rf
# [flaml.automl.logger: 09-25 00:41:22] {2391} INFO -  at 3827.6s,	estimator rf's best error=27.7725,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:41:22] {2218} INFO - iteration 87, current learner xgboost
# [flaml.automl.logger: 09-25 00:42:30] {2391} INFO -  at 3895.5s,	estimator xgboost's best error=27.5632,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:42:30] {2218} INFO - iteration 88, current learner xgboost
# [flaml.automl.logger: 09-25 00:42:55] {2391} INFO -  at 3921.0s,	estimator xgboost's best error=27.5632,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:42:55] {2218} INFO - iteration 89, current learner catboost
# [flaml.automl.logger: 09-25 00:47:08] {2391} INFO -  at 4173.6s,	estimator catboost's best error=27.4630,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:47:08] {2218} INFO - iteration 90, current learner rf
# [flaml.automl.logger: 09-25 00:47:58] {2391} INFO -  at 4224.2s,	estimator rf's best error=27.7725,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:47:58] {2218} INFO - iteration 91, current learner catboost
# [flaml.automl.logger: 09-25 00:51:17] {2391} INFO -  at 4423.2s,	estimator catboost's best error=27.4630,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:51:17] {2218} INFO - iteration 92, current learner rf
# [flaml.automl.logger: 09-25 00:52:18] {2391} INFO -  at 4484.0s,	estimator rf's best error=27.7725,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:52:18] {2218} INFO - iteration 93, current learner rf
# [flaml.automl.logger: 09-25 00:56:20] {2391} INFO -  at 4726.1s,	estimator rf's best error=27.6475,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 00:56:20] {2218} INFO - iteration 94, current learner lgbm
# [flaml.automl.logger: 09-25 01:02:56] {2391} INFO -  at 5121.5s,	estimator lgbm's best error=27.3977,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 01:02:56] {2218} INFO - iteration 95, current learner catboost
# [flaml.automl.logger: 09-25 01:05:36] {2391} INFO -  at 5281.8s,	estimator catboost's best error=27.4630,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 01:05:36] {2218} INFO - iteration 96, current learner xgboost
# [flaml.automl.logger: 09-25 01:12:15] {2391} INFO -  at 5681.2s,	estimator xgboost's best error=27.5632,	best estimator lgbm's best error=27.3977
# [flaml.automl.logger: 09-25 01:12:15] {2218} INFO - iteration 97, current learner rf
# [flaml.automl.logger: 09-25 01:17:53] {2391} INFO -  at 6018.6s,	estimator rf's best error=27.3167,	best estimator rf's best error=27.3167
# [flaml.automl.logger: 09-25 01:17:53] {2218} INFO - iteration 98, current learner xgboost
# [flaml.automl.logger: 09-25 01:19:02] {2391} INFO -  at 6087.3s,	estimator xgboost's best error=27.5632,	best estimator rf's best error=27.3167
# [flaml.automl.logger: 09-25 01:19:02] {2218} INFO - iteration 99, current learner lgbm
# [flaml.automl.logger: 09-25 01:22:01] {2391} INFO -  at 6266.9s,	estimator lgbm's best error=27.3977,	best estimator rf's best error=27.3167
# [flaml.automl.logger: 09-25 01:22:01] {2218} INFO - iteration 100, current learner catboost
# [flaml.automl.logger: 09-25 01:25:33] {2391} INFO -  at 6478.3s,	estimator catboost's best error=27.4630,	best estimator rf's best error=27.3167
# [flaml.automl.logger: 09-25 01:25:33] {2218} INFO - iteration 101, current learner rf
# [flaml.automl.logger: 09-25 01:28:31] {2391} INFO -  at 6657.2s,	estimator rf's best error=27.3167,	best estimator rf's best error=27.3167
# [flaml.automl.logger: 09-25 01:28:31] {2218} INFO - iteration 102, current learner lgbm
# [flaml.automl.logger: 09-25 01:29:09] {2391} INFO -  at 6694.8s,	estimator lgbm's best error=27.3977,	best estimator rf's best error=27.3167
# [flaml.automl.logger: 09-25 01:29:09] {2218} INFO - iteration 103, current learner rf
# [flaml.automl.logger: 09-25 01:40:22] {2391} INFO -  at 7367.8s,	estimator rf's best error=27.1866,	best estimator rf's best error=27.1866
# [flaml.automl.logger: 09-25 01:40:22] {2218} INFO - iteration 104, current learner xgboost
# [flaml.automl.logger: 09-25 01:42:23] {2391} INFO -  at 7488.7s,	estimator xgboost's best error=27.5632,	best estimator rf's best error=27.1866
# [flaml.automl.logger: 09-25 01:42:23] {2218} INFO - iteration 105, current learner xgboost
# [flaml.automl.logger: 09-25 01:47:05] {2391} INFO -  at 7770.6s,	estimator xgboost's best error=27.5632,	best estimator rf's best error=27.1866
# [flaml.automl.logger: 09-25 01:47:05] {2218} INFO - iteration 106, current learner catboost
# [flaml.automl.logger: 09-25 01:49:24] {2391} INFO -  at 7909.3s,	estimator catboost's best error=27.4630,	best estimator rf's best error=27.1866
# [flaml.automl.logger: 09-25 01:49:24] {2218} INFO - iteration 107, current learner xgboost
# [flaml.automl.logger: 09-25 01:50:03] {2391} INFO -  at 7948.8s,	estimator xgboost's best error=27.5632,	best estimator rf's best error=27.1866
# [flaml.automl.logger: 09-25 01:50:03] {2218} INFO - iteration 108, current learner catboost
# [flaml.automl.logger: 09-25 01:53:59] {2391} INFO -  at 8184.8s,	estimator catboost's best error=27.3900,	best estimator rf's best error=27.1866
# [flaml.automl.logger: 09-25 01:53:59] {2218} INFO - iteration 109, current learner rf
# [flaml.automl.logger: 09-25 02:26:23] {2391} INFO -  at 10128.3s,	estimator rf's best error=27.1412,	best estimator rf's best error=27.1412
# [flaml.automl.logger: 09-25 02:26:23] {2218} INFO - iteration 110, current learner lgbm
# [flaml.automl.logger: 09-25 02:31:42] {2391} INFO -  at 10447.9s,	estimator lgbm's best error=27.3977,	best estimator rf's best error=27.1412
# [flaml.automl.logger: 09-25 02:31:42] {2218} INFO - iteration 111, current learner catboost
# [flaml.automl.logger: 09-25 02:34:54] {2391} INFO -  at 10640.1s,	estimator catboost's best error=27.3900,	best estimator rf's best error=27.1412
# [flaml.automl.logger: 09-25 02:34:54] {2218} INFO - iteration 112, current learner rf
# [flaml.automl.logger: 09-25 03:38:46] {2391} INFO -  at 14471.8s,	estimator rf's best error=27.1412,	best estimator rf's best error=27.1412
# [flaml.automl.logger: 09-25 03:38:46] {2525} INFO - [('rf', {'n_jobs': -1, 'n_estimators': 836, 'max_features': 0.34639685768079054, 'max_leaf_nodes': 817, 'random_state': 12032022, 'verbose': 0}), ('catboost', {'early_stopping_rounds': 29, 'learning_rate': 0.039029743361978085, 'n_estimators': 331, 'thread_count': -1, 'verbose': False, 'random_seed': 10242048}), ('lgbm', {'n_jobs': -1, 'n_estimators': 253, 'num_leaves': 79, 'min_child_samples': 6, 'learning_rate': 0.08323749701463304, 'colsample_bytree': 0.8701628110747988, 'reg_alpha': 0.022118714435498076, 'reg_lambda': 0.0018503737816576763, 'max_bin': 127, 'verbose': -1}), ('xgboost', {'n_jobs': -1, 'n_estimators': 309, 'max_leaves': 8, 'min_child_weight': 0.6116643931318406, 'learning_rate': 0.0716121072972429, 'subsample': 1.0, 'colsample_bylevel': 0.9467432639496864, 'colsample_bytree': 0.9877878456495247, 'reg_alpha': 0.009754310579658875, 'reg_lambda': 0.005604519763167611, 'max_depth': 0, 'grow_policy': 'lossguide', 'tree_method': 'hist', 'use_label_encoder': False, 'verbosity': 0})]
# [flaml.automl.logger: 09-25 03:38:46] {2568} INFO - Building ensemble with tuned estimators
# [flaml.automl.logger: 09-25 04:21:49] {2574} INFO - ensemble: StackingRegressor(estimators=[('rf',
#                                <flaml.automl.model.RandomForestEstimator object at 0x0000020A653A8310>),
#                               ('catboost',
#                                <flaml.automl.model.CatBoostEstimator object at 0x0000020A0667F790>),
#                               ('lgbm',
#                                <flaml.automl.model.LGBMEstimator object at 0x0000020A0667FB50>),
#                               ('xgboost',
#                                <flaml.automl.model.XGBoostSklearnEstimator object at 0x0000020A0667F2B0>)],
#                   n_jobs=1, passthrough=True)
# [flaml.automl.logger: 09-25 04:21:49] {1930} INFO - fit succeeded
# [flaml.automl.logger: 09-25 04:21:49] {1931} INFO - Time taken to find the best model: 10128.25467991829
# [flaml.automl.logger: 09-25 04:21:49] {1941} WARNING - Time taken to find the best model is 70% of the provided time budget and not all estimators' hyperparameter search converged. Consider increasing the time budget.
# {'n_estimators': 836, 'max_features': 0.34639685768079054, 'max_leaves': 817}
# 27.141155745703458

# %% [markdown]
# - 1 : 32.53133291308737 : 알파벳 기준 평균화
# - 2 : 32.50343224854824 : 평균->범주화, bool 타입 살리기
# - 3 : 32.598785545609914 : 알파벳 앞 2개 기준 평균화, bool 타입 살리기
# - 4 : 32.59231590200649 : 알파벳 앞 2개 기준 평균화, bool 타입 살리기, int
# - 5 : 13.68499210379137 : 평균->범주화, bool 타입 살리기, Smoteenn(32142개)
# - 6 : 27.66777921166814 : 평균->범주화, bool 타입 살리기, Smoteenn(1500개)
# - 7 : 27점대 : 알파벳x(0만 drop), bool 타입 살리기, 언더샘플링(최종1100개)
# - 8 : 30.371972268239386 : 알파벳x(0만 drop), bool 타입 살리기, 언더샘플링(최종3000개)
# - 여기서부터 MLM 예측
# - 9 : 12.62284755465401 : 평균->범주화, bool 타입 살리기, Smoteenn(40000개)
# - 10 : 27.088651919701498 : 평균->범주화, bool 타입 살리기, Smoteenn(1500개)
# - 11 : 12.400419435221954 : 알파벳x(0만 drop), bool 타입 살리기, Smoteenn(50000개)
# - 12 : 27.482319519422198 : 알파벳x(0만 drop), bool 타입 살리기, Smoteenn(1500개)
# - 13 : 8.055969577263326 : 11번 df의 AutoML 앙상블
# - 14 : 26.365826007126714 : 12번 df의 AutoML 앙상블
# - 15 :  : 14번에서 target만 변경(MLM -> HML)

# %%
pred
# Out:
# array([37.75312425, 69.20118976, 62.08760455, 87.23299142, 79.17017994,
#        71.04430438, 55.63628742, 64.1029511 , 52.87686371, 60.42136582,
#        58.68955328, 72.00969595, 70.3679649 , 45.30627849, 21.53126829,
#        81.75294492, 59.68989234, 48.35031826, 82.5696034 , 81.38705455,
#        37.25415028, 15.07405344, 21.08208015, 51.15016829, 36.89079346,
#        54.28827747, 48.52134064, 87.73079568, 41.77196562, 72.12297711,
#        56.32390736, 44.97916853, 28.0197943 , 47.93629378, 48.39915358,
#        39.68482985, 35.86302765, 74.74207836, 63.20075363, 36.83709544,
#        51.184141  , 75.77217884, 26.50015115, 52.93854109, 33.46055822,
#        75.55491701, 52.52078143, 21.72741337, 86.33460627, 42.58598173,
#        83.63283697, 43.11113848, 47.21855489, 58.05079006, 50.32960445,
#        56.58422747, 59.16621738, 36.26388604, 24.19564102, 36.1952889 ,
#        34.07238002, 65.90770793, 47.98440197, 72.18291218, 38.16243333,
#        49.00991823, 63.99515738, 58.82208102, 75.37342831, 56.71524085,
#        61.54724415, 41.27379466, 41.37250685, 67.54598085, 45.60877085,
#        62.71690281, 56.39647229, 57.2254769 , 57.44485924, 46.78133092,
#        70.02101537, 77.74237788, 43.49364515, 29.57977046, 46.75125534,
#        88.06023937, 66.45556548, 92.10490828, 47.86389209, 58.40408217,
#        24.09585471, 43.61970122, 36.93849441, 40.26167164, 87.3790328 ,
#        35.28366336, 92.76464347, 52.02964974, 50.14824819, 33.52792214,
#        78.90301791, 26.14042051, 82.25812872, 70.37782888, 50.77328225,
#        78.02832663, 80.77938335, 73.568453  , 79.34906011, 39.6924403 ,
#        55.34194507, 65.04640816, 27.0455534 , 66.56132349, 54.67836692,
#        36.22830553, 37.94772053, 33.77091395, 76.14685469, 42.0757579 ,
#        84.64540298, 60.44631711, 28.47590083, 85.05314741, 51.52386774,
#        70.01046816, 55.40604818, 75.3706329 , 71.7394377 , 24.88345026,
#        69.9569238 , 51.11319218, 39.75689992, 69.13612222, 51.15895377,
#        57.12811077, 67.99148188, 43.94689874, 27.96889348, 57.43600546,
#        41.76696092, 31.18768646, 65.94016212, 39.46727135, 66.11602157,
#        39.63406278, 92.75644452, 74.00751089, 19.77752295, 70.11107137,
#        55.89216505, 74.31194508, 39.69884574, 31.05505852, 44.64752242,
#        64.85863214, 32.38260148, 47.8680013 , 43.42140527, 39.91351338,
#        92.6691507 , 71.91655321, 90.538884  , 66.81583951, 60.93679545,
#        41.18508953, 27.85672122, 77.0044791 , 56.2081904 , 43.62672911,
#        23.36100467, 62.61623225, 45.70446243, 20.3409597 , 82.21003539,
#        70.291162  , 51.69322901, 53.80593506, 59.79488963, 57.57114859,
#        54.58417138, 56.89845062, 63.73675582, 14.91118564, 65.78622507,
#        43.23584739, 43.01731831, 59.66478623, 29.63338371, 67.63188203,
#        80.55331142, 58.51484634, 46.4300837 , 72.7535663 , 53.4057284 ,
#        38.05443821, 72.19440911, 31.26085712, 73.71746443, 76.0114524 ,
#        66.42056645, 33.79066483, 79.87000833, 67.52771485, 42.01526582,
#        43.91958912, 33.99236745, 46.52112551, 38.82289245, 55.75338724,
#        57.61936396, 74.79774228, 45.8934481 , 28.90588517, 48.85319366,
#        62.50584971, 34.38530756, 77.30009983, 67.25482746, 43.93898007,
#        44.37820859, 49.69806665, 40.56310743, 86.99382389, 41.7192853 ,
#        37.50076607, 56.76165201, 35.39327369, 54.28783881, 37.47798905,
#        31.32228689, 53.110778  , 41.17738342, 63.10216584, 24.02121836,
#        59.36215767, 19.84669901, 44.10808983, 36.77167718, 71.1607965 ,
#        42.47070647, 75.50097548, 57.67923445, 36.20703912, 82.79033517,
#        72.42039698, 79.84315184, 61.90292485, 67.22469464, 56.36381555,
#        76.46904831, 56.9539212 , 67.66488262, 44.87264436, 83.51449261,
#        64.42893523, 73.84320991, 88.03933754, 68.1206801 , 83.71678507,
#        50.22130787, 77.84044735, 25.65286329, 41.73877186, 35.85070167,
#        47.93281168, 48.89124249, 68.69717464, 62.73702341, 37.30668006,
#        87.80953711, 50.71672673, 64.49671742, 62.17414877, 38.77150809,
#        61.2185242 , 73.45956586, 57.39483046, 43.69135722, 52.99401605,
#        39.06090719, 48.52077449, 46.40025996, 71.56003243, 50.57382478,
#        66.79107036, 81.34803621, 80.85671333, 69.94589927, 61.14196469,
#        37.34340272, 54.40857688, 43.01345189, 61.21834447, 49.31713276,
#        30.30311799, 43.04160081, 84.74265678, 51.22500235, 69.87509548,
#        62.54269801, 73.61508964, 73.59455968, 40.50908234, 38.20127794,
#        31.95630568, 86.37923617, 42.0830513 , 27.23479779, 56.20246997,
#        80.95183002, 64.59344515, 50.2871428 , 53.13258749, 37.906516  ,
#        61.3812645 , 20.40240602, 56.6324094 , 70.04221739, 54.86235371,
#        34.74746686, 64.9624222 , 71.80241454, 40.7171707 , 66.46696906,
#        59.91391267, 41.68968795, 97.66354553, 70.38337586, 37.97597647,
#        75.7092068 , 42.07536414, 51.55830928, 63.98884215, 83.59484927,
#        39.78022615, 40.16358684, 63.03991431, 40.56403162, 17.60651374,
#        38.1618401 , 70.34162385, 65.00391716, 77.25143347, 43.11779432,
#        36.01000785, 37.13687469, 69.09857753, 51.9979708 , 47.18009715,
#        20.05634434, 39.21758217, 18.69582127, 44.59977565, 55.60624111,
#        36.19546353, 72.54957649, 36.60400596, 35.28558391, 74.36960931,
#        48.13914121, 40.16256792, 66.10297793, 52.90550382, 65.70227185,
#        77.19369558,  1.69364278, 62.69577593, 75.76371048, 84.2886241 ,
#        60.80959755, 82.9916404 , 62.19531019, 18.77387535, 52.32044354,
#        69.38593875, 45.90818066, 50.82219491, 54.79382193, 43.37897859,
#        35.36028636, 58.46037649, 80.78472585, 28.90364344, 49.72891497,
#        70.12629649, 26.46569367, 75.75927085, 53.10496785, 41.79452748,
#        54.05402555, 56.86941694, 57.012345  , 66.84977667, 26.22721352,
#        41.97530834, 81.30851546, 38.00161736, 33.09619687, 84.35224591,
#        56.01904529, 45.99956504, 55.07299887, 58.72167335, 51.31217527,
#        47.58710276, 59.69592956, 75.88631209, 53.24028272, 58.52202271,
#        64.07152202, 51.46926459, 69.8547415 , 60.15284648, 79.34679189,
#        39.90044077, 88.0974652 , 40.58871593, 63.69897858, 73.09259006,
#        30.811215  , 72.52949212, 56.86049758, 41.2100139 , 52.59428456,
#        60.47126135, 69.94680812, 38.38578624, 69.22821311, 65.83134123,
#        80.4886002 , 79.57202981, 39.23294876, 83.35889594, 35.24466853,
#        60.21434089, 38.34690665, 82.26996821, 61.28721611, 32.57212734,
#        80.65842879, 69.8732935 , 47.33630499, 46.31835882, 49.33680537,
#        68.77109549, 52.5127291 , 67.76276596, 48.14645873, 47.23049012,
#        68.17817225, 65.18657833, 70.90484886, 82.84488476, 56.12391737,
#        50.87019383, 43.51661659, 30.05696094, 41.00337384, 42.90177254,
#        31.58336268, 81.89865944, 40.36836736, 36.33753497, 76.86315882,
#        36.18126509, 24.02191269, 78.76924062, 93.99509071, 45.43830383,
#        82.04771676, 58.88198843, 24.89282184, 35.95386731, 58.78231112,
#        62.84585877, 27.61278159, 35.52876138, 32.84151372, 94.82400306,
#        76.30193848, 72.64918616, 70.631693  ])

# %% [markdown]
# # 제출

# %%
submission = pd.read_csv(f"{DATA_PATH}sample_submission.csv")
submission
# Out:
#            id  MLM  HLM
# 0    TEST_000    0    0
# 1    TEST_001    0    0
# 2    TEST_002    0    0
# 3    TEST_003    0    0
# 4    TEST_004    0    0
# ..        ...  ...  ...
# 478  TEST_478    0    0
# 479  TEST_479    0    0
# 480  TEST_480    0    0
# 481  TEST_481    0    0
# 482  TEST_482    0    0
#
# [483 rows x 3 columns]

# %%
submission['HLM'] = pred
# submission['MLM'] = pred
submission
# Out:
#            id  MLM        HLM
# 0    TEST_000    0  37.753124
# 1    TEST_001    0  69.201190
# 2    TEST_002    0  62.087605
# 3    TEST_003    0  87.232991
# 4    TEST_004    0  79.170180
# ..        ...  ...        ...
# 478  TEST_478    0  32.841514
# 479  TEST_479    0  94.824003
# 480  TEST_480    0  76.301938
# 481  TEST_481    0  72.649186
# 482  TEST_482    0  70.631693
#
# [483 rows x 3 columns]

# %%
submission.to_csv(f"{DATA_PATH}aml_15_ensemble.csv", index=False)
submission.to_csv("aml_15_ensemble.csv", index=False)

# %%
ensemble = pd.read_csv(f"{DATA_PATH}ensemble.csv")
comparison = pd.concat([ensemble['HLM'],submission['HLM']], axis=1)

# 엑셀로 확인
with pd.ExcelWriter("comparison.xlsx", engine='openpyxl') as writer:
    comparison.to_excel(writer, sheet_name='시트1', index=False)
